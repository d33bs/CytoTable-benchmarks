# %% [markdown]
# # CytoTable (convert) and Pycytominer (SingleCells.merge_single_cells) Performance Comparisons
#
# This notebook explores CytoTable (convert) and Pycytominer (SingleCells.merge_single_cells) usage with datasets of varying size to help describe performance impacts.

# %%
# set ipyflow reactive mode
# %flow mode reactive

# %%
import io
import itertools
import json
import os
import pathlib
import subprocess
import tokenize
from datetime import datetime

import pandas as pd
import plotly.express as px
import plotly.io as pio
from IPython.display import Image

# set plotly default theme
pio.templates.default = "simple_white"

# %%
# observe the virtual env for dependency inheritance with memray
# from subprocedure calls
"/".join(
    subprocess.run(
        [
            "which",
            "memray",
        ],
        capture_output=True,
        check=True,
    )
    # decode bytestring as utf-8
    .stdout.decode("utf-8")
    # remove personal file structure
    .split("/")[6:]
    # replace final newline
).replace("\n", "")
# Out:
# 'virtualenvs/cytotable-benchmarks--NAtGS8s-py3.9/bin/memray'

# %%
# target file or table names
image_dir = "images"
examples_dir = "examples"
join_read_time_image = (
    f"{image_dir}/cytotable-and-pycytominer-comparisons-join-completion-time.png"
)
join_mem_size_image = (
    f"{image_dir}/cytotable-and-pycytominer-comparisons-join-memory-size.png"
)
example_files_list = [
    f"{examples_dir}/cytotable_convert_nf1.py",
    f"{examples_dir}/pycytominer_merge_nf1.py",
]
example_data_list = [
    f"{examples_dir}/data/all_cellprofiler.sqlite",
    f"{examples_dir}/data/all_cellprofiler-x2.sqlite",
    f"{examples_dir}/data/all_cellprofiler-x4.sqlite",
    f"{examples_dir}/data/all_cellprofiler-x8.sqlite",
    f"{examples_dir}/data/all_cellprofiler-x16.sqlite",
    f"{examples_dir}/data/all_cellprofiler-x32.sqlite",
    f"{examples_dir}/data/all_cellprofiler-x64.sqlite",
    f"{examples_dir}/data/all_cellprofiler-x128.sqlite",
    f"{examples_dir}/data/all_cellprofiler-x256.sqlite",
    f"{examples_dir}/data/all_cellprofiler-x512.sqlite",
]
# format for memray time strings
tformat = "%Y-%m-%d %H:%M:%S.%f"

# %%
# result list for storing data
results = []

# loop for iterating over examples and example data
# and gathering data about operations on them
for example_file, example_data in itertools.product(
    example_files_list,
    example_data_list,
):
    target_bin = f"{example_file}_with_{example_data.replace(f'{examples_dir}/data/','')}.memray.bin"
    target_json = f"{target_bin}.json"
    memray_run = subprocess.run(
        [
            "memray",
            "run",
            "--follow-fork",
            "--output",
            target_bin,
            "--force",
            example_file,
            example_data,
        ],
        capture_output=True,
        check=True,
    )

    memray_stats = subprocess.run(
        [
            "memray",
            "stats",
            "--json",
            "--output",
            target_json,
            "--force",
            target_bin,
        ],
        capture_output=True,
        check=True,
    )

    # open the json data
    with open(target_json) as memray_json_file:
        memray_data = json.load(memray_json_file)

    # append data to the result list
    results.append(
        {
            # general information about the dataframe
            "file_input": example_file.replace(f"{examples_dir}/", ""),
            "data_input": example_data,
            # information about pandas
            "time_duration (secs)": (
                datetime.strptime(memray_data["metadata"]["end_time"], tformat)
                - datetime.strptime(memray_data["metadata"]["start_time"], tformat)
            ).total_seconds(),
            "total_memory (bytes)": memray_data["total_bytes_allocated"],
        }
    )

    # cleanup
    pathlib.Path(target_bin).unlink(missing_ok=True)
    pathlib.Path(target_json).unlink(missing_ok=True)

df_results = pd.DataFrame(results)
df_results
# Out:
#                   file_input                                  data_input  \
# 0   cytotable_convert_nf1.py       examples/data/all_cellprofiler.sqlite
# 1   cytotable_convert_nf1.py    examples/data/all_cellprofiler-x2.sqlite
# 2   cytotable_convert_nf1.py    examples/data/all_cellprofiler-x4.sqlite
# 3   cytotable_convert_nf1.py    examples/data/all_cellprofiler-x8.sqlite
# 4   cytotable_convert_nf1.py   examples/data/all_cellprofiler-x16.sqlite
# 5   cytotable_convert_nf1.py   examples/data/all_cellprofiler-x32.sqlite
# 6   cytotable_convert_nf1.py   examples/data/all_cellprofiler-x64.sqlite
# 7   cytotable_convert_nf1.py  examples/data/all_cellprofiler-x128.sqlite
# 8   cytotable_convert_nf1.py  examples/data/all_cellprofiler-x256.sqlite
# 9   cytotable_convert_nf1.py  examples/data/all_cellprofiler-x512.sqlite
# 10  pycytominer_merge_nf1.py       examples/data/all_cellprofiler.sqlite
# 11  pycytominer_merge_nf1.py    examples/data/all_cellprofiler-x2.sqlite
# 12  pycytominer_merge_nf1.py    examples/data/all_cellprofiler-x4.sqlite
# 13  pycytominer_merge_nf1.py    examples/data/all_cellprofiler-x8.sqlite
# 14  pycytominer_merge_nf1.py   examples/data/all_cellprofiler-x16.sqlite
# 15  pycytominer_merge_nf1.py   examples/data/all_cellprofiler-x32.sqlite
# 16  pycytominer_merge_nf1.py   examples/data/all_cellprofiler-x64.sqlite
# 17  pycytominer_merge_nf1.py  examples/data/all_cellprofiler-x128.sqlite
# 18  pycytominer_merge_nf1.py  examples/data/all_cellprofiler-x256.sqlite
# 19  pycytominer_merge_nf1.py  examples/data/all_cellprofiler-x512.sqlite
#
#     time_duration (secs)  total_memory (bytes)
# 0                  7.932             252070512
# 1                  6.929             252073427
# 2                  7.026             252057830
# 3                  7.054             252075633
# 4                  7.575             285632297
# 5                  8.966             252167012
# 6                 10.612             319297415
# 7                 12.792             353099524
# 8                 20.013             286353277
# 9                 36.182             254600789
# 10                 1.761             585904201
# 11                 1.236             650152601
# 12                 1.520             918418684
# 13                 1.890            1118244567
# 14                 2.832            1618575957
# 15                 4.842            2687154132
# 16                 9.106            4958180172
# 17                18.143            9227254820
# 18                39.754           18034137431
# 19               133.685           35846781057

# %%
# add columns for data understandability in plots


def get_file_size_mb(file_path):
    """
    Gather filesize given a file_path
    """
    try:
        return pathlib.Path(file_path).stat().st_size / 1024 / 1024
    except FileNotFoundError:
        return None


# memory usage in MB
df_results["total_memory (GB)"] = (
    df_results["total_memory (bytes)"] / 1024 / 1024 / 1024
)

# data input size additions for greater context
df_results["data_input_size_mb"] = df_results["data_input"].apply(get_file_size_mb)
df_results["data_input_with_size"] = (
    df_results["data_input"]
    + " ("
    + round(df_results["data_input_size_mb"]).astype("int64").astype("str")
    + " MB)"
)

# rename data input to simplify
df_results["data_input_renamed"] = (
    df_results["data_input_with_size"]
    .str.replace(f"{examples_dir}/data/", "")
    .str.replace("all_cellprofiler", "input")
)
df_results
# Out:
#                   file_input                                  data_input  \
# 0   cytotable_convert_nf1.py       examples/data/all_cellprofiler.sqlite
# 1   cytotable_convert_nf1.py    examples/data/all_cellprofiler-x2.sqlite
# 2   cytotable_convert_nf1.py    examples/data/all_cellprofiler-x4.sqlite
# 3   cytotable_convert_nf1.py    examples/data/all_cellprofiler-x8.sqlite
# 4   cytotable_convert_nf1.py   examples/data/all_cellprofiler-x16.sqlite
# 5   cytotable_convert_nf1.py   examples/data/all_cellprofiler-x32.sqlite
# 6   cytotable_convert_nf1.py   examples/data/all_cellprofiler-x64.sqlite
# 7   cytotable_convert_nf1.py  examples/data/all_cellprofiler-x128.sqlite
# 8   cytotable_convert_nf1.py  examples/data/all_cellprofiler-x256.sqlite
# 9   cytotable_convert_nf1.py  examples/data/all_cellprofiler-x512.sqlite
# 10  pycytominer_merge_nf1.py       examples/data/all_cellprofiler.sqlite
# 11  pycytominer_merge_nf1.py    examples/data/all_cellprofiler-x2.sqlite
# 12  pycytominer_merge_nf1.py    examples/data/all_cellprofiler-x4.sqlite
# 13  pycytominer_merge_nf1.py    examples/data/all_cellprofiler-x8.sqlite
# 14  pycytominer_merge_nf1.py   examples/data/all_cellprofiler-x16.sqlite
# 15  pycytominer_merge_nf1.py   examples/data/all_cellprofiler-x32.sqlite
# 16  pycytominer_merge_nf1.py   examples/data/all_cellprofiler-x64.sqlite
# 17  pycytominer_merge_nf1.py  examples/data/all_cellprofiler-x128.sqlite
# 18  pycytominer_merge_nf1.py  examples/data/all_cellprofiler-x256.sqlite
# 19  pycytominer_merge_nf1.py  examples/data/all_cellprofiler-x512.sqlite
#
#     time_duration (secs)  total_memory (bytes)  total_memory (GB)  \
# 0                  7.932             252070512           0.234759
# 1                  6.929             252073427           0.234762
# 2                  7.026             252057830           0.234747
# 3                  7.054             252075633           0.234764
# 4                  7.575             285632297           0.266016
# 5                  8.966             252167012           0.234849
# 6                 10.612             319297415           0.297369
# 7                 12.792             353099524           0.328850
# 8                 20.013             286353277           0.266687
# 9                 36.182             254600789           0.237115
# 10                 1.761             585904201           0.545666
# 11                 1.236             650152601           0.605502
# 12                 1.520             918418684           0.855344
# 13                 1.890            1118244567           1.041446
# 14                 2.832            1618575957           1.507416
# 15                 4.842            2687154132           2.502607
# 16                 9.106            4958180172           4.617665
# 17                18.143            9227254820           8.593551
# 18                39.754           18034137431          16.795599
# 19               133.685           35846781057          33.384916
#
#     data_input_size_mb                               data_input_with_size  \
# 0             3.843750       examples/data/all_cellprofiler.sqlite (4 MB)
# 1             7.578125    examples/data/all_cellprofiler-x2.sqlite (8 MB)
# 2            15.031250   examples/data/all_cellprofiler-x4.sqlite (15 MB)
# 3            29.937500   examples/data/all_cellprofiler-x8.sqlite (30 MB)
# 4            59.765625  examples/data/all_cellprofiler-x16.sqlite (60 MB)
# 5           119.390625  examples/data/all_cellprofiler-x32.sqlite (119...
# 6           238.683594  examples/data/all_cellprofiler-x64.sqlite (239...
# 7           477.300781  examples/data/all_cellprofiler-x128.sqlite (47...
# 8           954.632812  examples/data/all_cellprofiler-x256.sqlite (95...
# 9          1909.335938  examples/data/all_cellprofiler-x512.sqlite (19...
# 10            3.843750       examples/data/all_cellprofiler.sqlite (4 MB)
# 11            7.578125    examples/data/all_cellprofiler-x2.sqlite (8 MB)
# 12           15.031250   examples/data/all_cellprofiler-x4.sqlite (15 MB)
# 13           29.937500   examples/data/all_cellprofiler-x8.sqlite (30 MB)
# 14           59.765625  examples/data/all_cellprofiler-x16.sqlite (60 MB)
# 15          119.390625  examples/data/all_cellprofiler-x32.sqlite (119...
# 16          238.683594  examples/data/all_cellprofiler-x64.sqlite (239...
# 17          477.300781  examples/data/all_cellprofiler-x128.sqlite (47...
# 18          954.632812  examples/data/all_cellprofiler-x256.sqlite (95...
# 19         1909.335938  examples/data/all_cellprofiler-x512.sqlite (19...
#
#              data_input_renamed
# 0           input.sqlite (4 MB)
# 1        input-x2.sqlite (8 MB)
# 2       input-x4.sqlite (15 MB)
# 3       input-x8.sqlite (30 MB)
# 4      input-x16.sqlite (60 MB)
# 5     input-x32.sqlite (119 MB)
# 6     input-x64.sqlite (239 MB)
# 7    input-x128.sqlite (477 MB)
# 8    input-x256.sqlite (955 MB)
# 9   input-x512.sqlite (1909 MB)
# 10          input.sqlite (4 MB)
# 11       input-x2.sqlite (8 MB)
# 12      input-x4.sqlite (15 MB)
# 13      input-x8.sqlite (30 MB)
# 14     input-x16.sqlite (60 MB)
# 15    input-x32.sqlite (119 MB)
# 16    input-x64.sqlite (239 MB)
# 17   input-x128.sqlite (477 MB)
# 18   input-x256.sqlite (955 MB)
# 19  input-x512.sqlite (1909 MB)

# %%
# build cols for split reference in the plot
df_results["cytotable_time_duration (secs)"] = df_results[
    df_results["file_input"] == "cytotable_convert_nf1.py"
]["time_duration (secs)"]
df_results["cytotable_total_memory (GB)"] = df_results[
    df_results["file_input"] == "cytotable_convert_nf1.py"
]["total_memory (GB)"]
df_results["pycytominer_time_duration (secs)"] = df_results[
    df_results["file_input"] == "pycytominer_merge_nf1.py"
]["time_duration (secs)"]
df_results["pycytominer_total_memory (GB)"] = df_results[
    df_results["file_input"] == "pycytominer_merge_nf1.py"
]["total_memory (GB)"]
df_results = (
    df_results.apply(lambda x: pd.Series(x.dropna().values))
    .drop(["file_input", "time_duration (secs)", "total_memory (GB)"], axis=1)
    .dropna()
)
df_results
# Out:
#                                    data_input  total_memory (bytes)  \
# 0       examples/data/all_cellprofiler.sqlite             252070512
# 1    examples/data/all_cellprofiler-x2.sqlite             252073427
# 2    examples/data/all_cellprofiler-x4.sqlite             252057830
# 3    examples/data/all_cellprofiler-x8.sqlite             252075633
# 4   examples/data/all_cellprofiler-x16.sqlite             285632297
# 5   examples/data/all_cellprofiler-x32.sqlite             252167012
# 6   examples/data/all_cellprofiler-x64.sqlite             319297415
# 7  examples/data/all_cellprofiler-x128.sqlite             353099524
# 8  examples/data/all_cellprofiler-x256.sqlite             286353277
# 9  examples/data/all_cellprofiler-x512.sqlite             254600789
#
#    data_input_size_mb                               data_input_with_size  \
# 0            3.843750       examples/data/all_cellprofiler.sqlite (4 MB)
# 1            7.578125    examples/data/all_cellprofiler-x2.sqlite (8 MB)
# 2           15.031250   examples/data/all_cellprofiler-x4.sqlite (15 MB)
# 3           29.937500   examples/data/all_cellprofiler-x8.sqlite (30 MB)
# 4           59.765625  examples/data/all_cellprofiler-x16.sqlite (60 MB)
# 5          119.390625  examples/data/all_cellprofiler-x32.sqlite (119...
# 6          238.683594  examples/data/all_cellprofiler-x64.sqlite (239...
# 7          477.300781  examples/data/all_cellprofiler-x128.sqlite (47...
# 8          954.632812  examples/data/all_cellprofiler-x256.sqlite (95...
# 9         1909.335938  examples/data/all_cellprofiler-x512.sqlite (19...
#
#             data_input_renamed  cytotable_time_duration (secs)  \
# 0          input.sqlite (4 MB)                           7.932
# 1       input-x2.sqlite (8 MB)                           6.929
# 2      input-x4.sqlite (15 MB)                           7.026
# 3      input-x8.sqlite (30 MB)                           7.054
# 4     input-x16.sqlite (60 MB)                           7.575
# 5    input-x32.sqlite (119 MB)                           8.966
# 6    input-x64.sqlite (239 MB)                          10.612
# 7   input-x128.sqlite (477 MB)                          12.792
# 8   input-x256.sqlite (955 MB)                          20.013
# 9  input-x512.sqlite (1909 MB)                          36.182
#
#    cytotable_total_memory (GB)  pycytominer_time_duration (secs)  \
# 0                     0.234759                             1.761
# 1                     0.234762                             1.236
# 2                     0.234747                             1.520
# 3                     0.234764                             1.890
# 4                     0.266016                             2.832
# 5                     0.234849                             4.842
# 6                     0.297369                             9.106
# 7                     0.328850                            18.143
# 8                     0.266687                            39.754
# 9                     0.237115                           133.685
#
#    pycytominer_total_memory (GB)
# 0                       0.545666
# 1                       0.605502
# 2                       0.855344
# 3                       1.041446
# 4                       1.507416
# 5                       2.502607
# 6                       4.617665
# 7                       8.593551
# 8                      16.795599
# 9                      33.384916

# %%
# read time chart
fig = px.line(
    df_results,
    y=[
        "cytotable_time_duration (secs)",
        "pycytominer_time_duration (secs)",
    ],
    x="data_input_renamed",
    title="CytoTable and Pycytominer SQLite Processing Time Comparison",
    labels={"data_input_renamed": "Input File", "value": "Seconds"},
    height=500,
    width=900,
    symbol_sequence=["diamond"],
    color_discrete_sequence=[
        px.colors.qualitative.Vivid[6],
        px.colors.qualitative.Vivid[4],
    ],
)

# rename the lines for the legend
newnames = {
    "cytotable_time_duration (secs)": "CytoTable",
    "pycytominer_time_duration (secs)": "Pycytominer",
}
# referenced from: https://stackoverflow.com/a/64378982
fig.for_each_trace(
    lambda t: t.update(
        name=newnames[t.name],
        legendgroup=newnames[t.name],
        hovertemplate=t.hovertemplate.replace(t.name, newnames[t.name]),
    )
)

# update the legend
fig.update_layout(
    legend_title_text="",
    legend=dict(x=0.01, y=0.98, bgcolor="rgba(255,255,255,0.8)"),
    font=dict(
        size=16,  # global font size
    ),
)
# fig.update_xaxes(range=[-0.03, 5.2])
fig.update_traces(mode="lines+markers")

fig.write_image(join_read_time_image)
fig.write_image(join_read_time_image.replace(".png", ".svg"))
Image(url=join_read_time_image.replace(".png", ".svg"))
# Out:
# <img src="images/cytotable-and-pycytominer-comparisons-join-completion-time.svg"/>

# %%
# memory size

fig = px.line(
    df_results,
    y=[
        "cytotable_total_memory (GB)",
        "pycytominer_total_memory (GB)",
    ],
    x="data_input_renamed",
    title="CytoTable and Pycytominer SQLite Total Memory Consumption",
    labels={"data_input_renamed": "Input File", "value": "Gigabytes (GB)"},
    height=500,
    width=900,
    symbol_sequence=["diamond"],
    color_discrete_sequence=[
        px.colors.qualitative.Vivid[6],
        px.colors.qualitative.Vivid[4],
    ],
)

# rename the lines for the legend
newnames = {
    "cytotable_total_memory (GB)": "CytoTable",
    "pycytominer_total_memory (GB)": "Pycytominer",
}
# referenced from: https://stackoverflow.com/a/64378982
fig.for_each_trace(
    lambda t: t.update(
        name=newnames[t.name],
        legendgroup=newnames[t.name],
        hovertemplate=t.hovertemplate.replace(t.name, newnames[t.name]),
    )
)

# update the legend
fig.update_layout(
    legend_title_text="",
    legend=dict(x=0.01, y=0.98, bgcolor="rgba(255,255,255,0.8)"),
    font=dict(
        size=16,  # global font size
    ),
)
fig.update_traces(mode="lines+markers")


fig.write_image(join_mem_size_image)
fig.write_image(join_mem_size_image.replace(".png", ".svg"))
Image(url=join_mem_size_image.replace(".png", ".svg"))
# Out:
# <img src="images/cytotable-and-pycytominer-comparisons-join-memory-size.svg"/>
