# %% [markdown]
# # CytoTable object graph analysis
#
# This notebook explores how CytoTable objects operate. The work is related to [CytoTable#75](https://github.com/cytomining/CytoTable/issues/75).

# %%
import gc
import pathlib
import sys

import cytotable
import pandas as pd

gc.set_debug(gc.DEBUG_LEAK)

cytotable.convert(
    source_path="../examples/data/all_cellprofiler.sqlite",
    dest_path="./examples/data/test-result.parquet",
    dest_datatype="parquet",
    preset="cellprofiler_sqlite_pycytominer",
)

collected = gc.collect()
if gc.garbage:
    print(f"Memory leak detected: {len(gc.garbage)} objects")
    df = pd.DataFrame(
        [
            {
                "id": id(obj),
                "type": type(obj),
                "refcount": sys.getrefcount(obj),
                "repr": repr(obj),
                "size": sys.getsizeof(obj),
            }
            for obj in gc.garbage
        ]
    )

df.head()
# Out:
# Memory leak detected: 1119 objects
# gc: collectable <list 0x14e9aca80>
# gc: collectable <list 0x13f569740>
# gc: collectable <dict 0x14e9c5a00>
# gc: collectable <AppFuture 0x13ef3fa00>
# gc: collectable <Condition 0x13ef3fd30>
# gc: collectable <builtin_function_or_method 0x14ebec900>
# gc: collectable <dict 0x13f3e2780>
# gc: collectable <builtin_function_or_method 0x14ebec950>
# gc: collectable <builtin_function_or_method 0x14ebec9a0>
# gc: collectable <builtin_function_or_method 0x14ebec9f0>
# gc: collectable <builtin_function_or_method 0x14ebeca40>
# gc: collectable <collections.deque 0x12a373760>
# gc: collectable <dict 0x14e9b23c0>
# gc: collectable <list 0x13f569180>
# gc: collectable <list 0x14e9ac680>
# gc: collectable <list 0x14e9ac700>
# gc: collectable <list 0x14ebe39c0>
# gc: collectable <method 0x14ebe3a00>
# gc: collectable <functools.partial 0x14ebecae0>
# gc: collectable <tuple 0x10770b550>
# gc: collectable <list 0x13f5690c0>
# gc: collectable <Future 0x13ef3fc10>
# gc: collectable <Condition 0x13ef3fb80>
# gc: collectable <builtin_function_or_method 0x14ebecbd0>
# gc: collectable <dict 0x14ea59b80>
# gc: collectable <builtin_function_or_method 0x14ebeccc0>
# gc: collectable <builtin_function_or_method 0x14ebecd10>
# gc: collectable <builtin_function_or_method 0x14ebecd60>
# gc: collectable <builtin_function_or_method 0x14ebecdb0>
# gc: collectable <collections.deque 0x13f56d1c0>
# gc: collectable <dict 0x14ea59580>
# gc: collectable <list 0x13f569080>
# gc: collectable <list 0x14eafcf80>
# gc: collectable <method 0x14ebe3980>
# gc: collectable <functools.partial 0x14ebecb80>
# gc: collectable <tuple 0x1295d7970>
# gc: collectable <list 0x14eafc9c0>
# gc: collectable <dict 0x107759240>
# gc: collectable <list 0x14ebf4ac0>
# gc: collectable <list 0x14eafc900>
# gc: collectable <dict 0x14ebf4740>
# gc: collectable <AppFuture 0x13eee6280>
# gc: collectable <Condition 0x13eee62b0>
# gc: collectable <builtin_function_or_method 0x1296a2590>
# gc: collectable <dict 0x1295e9800>
# gc: collectable <builtin_function_or_method 0x14ebf10e0>
# gc: collectable <builtin_function_or_method 0x14ebf1130>
# gc: collectable <builtin_function_or_method 0x14ebf1400>
# gc: collectable <builtin_function_or_method 0x14ebf1450>
# gc: collectable <collections.deque 0x14ea7db20>
# gc: collectable <dict 0x14eae0540>
# gc: collectable <list 0x14eafc880>
# gc: collectable <list 0x14eafc800>
# gc: collectable <list 0x14eafc680>
# gc: collectable <list 0x14ebf4c40>
# gc: collectable <method 0x14ebf4b00>
# gc: collectable <functools.partial 0x14ebf14f0>
# gc: collectable <tuple 0x13eca8340>
# gc: collectable <list 0x13f582c80>
# gc: collectable <Future 0x13eee6910>
# gc: collectable <Condition 0x13eee6940>
# gc: collectable <builtin_function_or_method 0x14ebf1540>
# gc: collectable <dict 0x14ebf4c00>
# gc: collectable <builtin_function_or_method 0x14ebf16d0>
# gc: collectable <builtin_function_or_method 0x14ebf1720>
# gc: collectable <builtin_function_or_method 0x14ebf1770>
# gc: collectable <builtin_function_or_method 0x14ebf17c0>
# gc: collectable <collections.deque 0x14ea6d3a0>
# gc: collectable <dict 0x14ebf4d00>
# gc: collectable <list 0x13f3be200>
# gc: collectable <list 0x13f3be140>
# gc: collectable <list 0x13f3acf40>
# gc: collectable <list 0x13f545c40>
# gc: collectable <dict 0x14ebf8200>
# gc: collectable <AppFuture 0x13e7b2550>
# gc: collectable <Condition 0x13e7b2520>
# gc: collectable <builtin_function_or_method 0x14ebf15e0>
# gc: collectable <dict 0x14ebf8280>
# gc: collectable <builtin_function_or_method 0x14ebf1a90>
# gc: collectable <builtin_function_or_method 0x14ebf1630>
# gc: collectable <builtin_function_or_method 0x14ebf1680>
# gc: collectable <builtin_function_or_method 0x14ebf1ae0>
# gc: collectable <collections.deque 0x14eb27fa0>
# gc: collectable <dict 0x14ebf4bc0>
# gc: collectable <list 0x14e9b2ac0>
# gc: collectable <list 0x14ea6e280>
# gc: collectable <method 0x14ebf4b40>
# gc: collectable <functools.partial 0x14ebf1590>
# gc: collectable <tuple 0x11df3c5e0>
# gc: collectable <list 0x14eafc740>
# gc: collectable <list 0x14ebf4080>
# gc: collectable <method 0x14ebf4040>
# gc: collectable <functools.partial 0x14ebf1bd0>
# gc: collectable <tuple 0x13f3c7520>
# gc: collectable <list 0x14ebf82c0>
# gc: collectable <Future 0x13eee6c10>
# gc: collectable <Condition 0x13eee69a0>
# gc: collectable <builtin_function_or_method 0x14ebf1b80>
# gc: collectable <dict 0x14ebf4900>
# gc: collectable <builtin_function_or_method 0x14ebf1d60>
# gc: collectable <builtin_function_or_method 0x14ebf1db0>
# gc: collectable <builtin_function_or_method 0x14ebf1e00>
# gc: collectable <builtin_function_or_method 0x14ebf1e50>
# gc: collectable <collections.deque 0x14eb2b040>
# gc: collectable <dict 0x14ebf8240>
# gc: collectable <list 0x14ebf81c0>
# gc: collectable <list 0x14ebf84c0>
# gc: collectable <cell 0x13e7b21c0>
# gc: collectable <cell 0x13e7b2190>
# gc: collectable <cell 0x13e7b2160>
# gc: collectable <cell 0x13e7b2130>
# gc: collectable <cell 0x13e7b2af0>
# gc: collectable <tuple 0x14eb16ae0>
# gc: collectable <function 0x14ebfc040>
# gc: collectable <method 0x14ebf4f00>
# gc: collectable <functools.partial 0x14ebf1c20>
# gc: collectable <tuple 0x13f3c75b0>
# gc: collectable <dict 0x14ebe3fc0>
# gc: collectable <cell 0x13eee64f0>
# gc: collectable <cell 0x13eee6520>
# gc: collectable <list 0x13f3acf00>
# gc: collectable <list 0x14ebf86c0>
# gc: collectable <dict 0x14ebf8440>
# gc: collectable <AppFuture 0x13e7b2ac0>
# gc: collectable <Condition 0x13e7b2280>
# gc: collectable <builtin_function_or_method 0x14ebf1c70>
# gc: collectable <dict 0x14ebf8980>
# gc: collectable <builtin_function_or_method 0x14ebf91d0>
# gc: collectable <builtin_function_or_method 0x14ebf9220>
# gc: collectable <builtin_function_or_method 0x14ebf9270>
# gc: collectable <builtin_function_or_method 0x14ebf92c0>
# gc: collectable <collections.deque 0x14eb44880>
# gc: collectable <dict 0x14ebf8800>
# gc: collectable <list 0x14ebf8a40>
# gc: collectable <list 0x14ebf8ac0>
# gc: collectable <list 0x14ebf8680>
# gc: collectable <list 0x14ebf8940>
# gc: collectable <method 0x14ebf8c00>
# gc: collectable <functools.partial 0x14ebf9400>
# gc: collectable <tuple 0x13f3c76d0>
# gc: collectable <tuple 0x1295f2800>
# gc: collectable <function 0x14ebfc280>
# gc: collectable <dict 0x14ebf8c80>
# gc: collectable <cell 0x13e7b2670>
# gc: collectable <cell 0x13e7b25b0>
# gc: collectable <list 0x14ebf8300>
# gc: collectable <list 0x14ebf89c0>
# gc: collectable <dict 0x14ebf8dc0>
# gc: collectable <AppFuture 0x13e7b2a60>
# gc: collectable <Condition 0x13e7b2400>
# gc: collectable <builtin_function_or_method 0x14ebf93b0>
# gc: collectable <dict 0x14ebf8e00>
# gc: collectable <builtin_function_or_method 0x14ebf9450>
# gc: collectable <builtin_function_or_method 0x14ebf94a0>
# gc: collectable <builtin_function_or_method 0x14ebf9360>
# gc: collectable <builtin_function_or_method 0x14ebf94f0>
# gc: collectable <collections.deque 0x14eb57a60>
# gc: collectable <dict 0x14ebf8cc0>
# gc: collectable <list 0x14ebf8d00>
# gc: collectable <list 0x14ebf8d80>
# gc: collectable <list 0x14ebf8e80>
# gc: collectable <list 0x14ebf8ec0>
# gc: collectable <method 0x14ebfe0c0>
# gc: collectable <functools.partial 0x14ebf9630>
# gc: collectable <tuple 0x13f365fd0>
# gc: collectable <tuple 0x1188f6f00>
# gc: collectable <function 0x14ebfc310>
# gc: collectable <dict 0x14ebf8fc0>
# gc: collectable <cell 0x13e7b23d0>
# gc: collectable <cell 0x13e7b2700>
# gc: collectable <list 0x14ebf8380>
# gc: collectable <list 0x14ebf8e40>
# gc: collectable <dict 0x14ebfe180>
# gc: collectable <AppFuture 0x13e7b2880>
# gc: collectable <Condition 0x13e7b2310>
# gc: collectable <builtin_function_or_method 0x14ebf95e0>
# gc: collectable <dict 0x14ebfe1c0>
# gc: collectable <builtin_function_or_method 0x14ebf9680>
# gc: collectable <builtin_function_or_method 0x14ebf96d0>
# gc: collectable <builtin_function_or_method 0x14ebf9590>
# gc: collectable <builtin_function_or_method 0x14ebf9720>
# gc: collectable <collections.deque 0x14eb5a0a0>
# gc: collectable <dict 0x14ebfe040>
# gc: collectable <list 0x14ebfe100>
# gc: collectable <list 0x14ebfe140>
# gc: collectable <list 0x14ebfe240>
# gc: collectable <list 0x14ebfe280>
# gc: collectable <method 0x14ebfe400>
# gc: collectable <functools.partial 0x14ebf9860>
# gc: collectable <tuple 0x13f3c7730>
# gc: collectable <tuple 0x1295f2640>
# gc: collectable <function 0x14ebfc3a0>
# gc: collectable <tuple 0x1188f9840>
# gc: collectable <function 0x14ebfc430>
# gc: collectable <method 0x13ec983c0>
# gc: collectable <functools.partial 0x14ebf98b0>
# gc: collectable <tuple 0x12f790850>
# gc: collectable <PosixPath 0x14eb449a0>
# gc: collectable <list 0x14ebf8140>
# gc: collectable <list 0x14ebf8100>
# gc: collectable <Future 0x13e78c9a0>
# gc: collectable <Condition 0x13e78c400>
# gc: collectable <builtin_function_or_method 0x14ebf9bd0>
# gc: collectable <dict 0x14ebf4a80>
# gc: collectable <builtin_function_or_method 0x14ebf9db0>
# gc: collectable <builtin_function_or_method 0x14ebf9e00>
# gc: collectable <builtin_function_or_method 0x14ebf9e50>
# gc: collectable <builtin_function_or_method 0x14ebf9ea0>
# gc: collectable <collections.deque 0x14eb448e0>
# gc: collectable <dict 0x14ebf4cc0>
# gc: collectable <list 0x14ebf8f40>
# gc: collectable <list 0x14ebfe200>
# gc: collectable <method 0x14ea11dc0>
# gc: collectable <functools.partial 0x14ebf9c70>
# gc: collectable <tuple 0x13f30ec40>
# gc: collectable <list 0x14ebfe800>
# gc: collectable <list 0x14ebfe4c0>
# gc: collectable <PosixPath 0x14eb5a100>
# gc: collectable <dict 0x14ebf40c0>
# gc: collectable <dict 0x14ebfe580>
# gc: collectable <list 0x14ebf8a80>
# gc: collectable <list 0x14ebf8900>
# gc: collectable <PosixPath 0x14ebe0f40>
# gc: collectable <dict 0x14ebfe700>
# gc: collectable <list 0x14ebfecc0>
# gc: collectable <list 0x14ebfee00>
# gc: collectable <PosixPath 0x14ebe40a0>
# gc: collectable <dict 0x14ebfeb00>
# gc: collectable <list 0x14ebfe640>
# gc: collectable <list 0x14ebfeb80>
# gc: collectable <PosixPath 0x14ebe88e0>
# gc: collectable <dict 0x14ebfeb40>
# gc: collectable <list 0x14ebfe840>
# gc: collectable <Future 0x14e9c80d0>
# gc: collectable <Condition 0x14e9c80a0>
# gc: collectable <builtin_function_or_method 0x14ebff2c0>
# gc: collectable <dict 0x14ebf8400>
# gc: collectable <builtin_function_or_method 0x14ebff540>
# gc: collectable <builtin_function_or_method 0x14ebff590>
# gc: collectable <builtin_function_or_method 0x14ebff5e0>
# gc: collectable <builtin_function_or_method 0x14ebff630>
# gc: collectable <collections.deque 0x14eba7760>
# gc: collectable <dict 0x14ebf8700>
# gc: collectable <list 0x14ebfed00>
# gc: collectable <list 0x14ebfed40>
# gc: collectable <list 0x14ebfed80>
# gc: collectable <Future 0x14e9c8130>
# gc: collectable <Condition 0x14e9c8160>
# gc: collectable <builtin_function_or_method 0x14ebff4a0>
# gc: collectable <dict 0x14ebfe540>
# gc: collectable <builtin_function_or_method 0x14ebff7c0>
# gc: collectable <builtin_function_or_method 0x14ebff810>
# gc: collectable <builtin_function_or_method 0x14ebff860>
# gc: collectable <builtin_function_or_method 0x14ebff8b0>
# gc: collectable <collections.deque 0x14ebad4c0>
# gc: collectable <dict 0x14ebfe6c0>
# gc: collectable <list 0x14ebfedc0>
# gc: collectable <list 0x14ebfec40>
# gc: collectable <list 0x14ebfef40>
# gc: collectable <method 0x14ebfe9c0>
# gc: collectable <functools.partial 0x14ebff4f0>
# gc: collectable <tuple 0x13ea2b730>
# gc: collectable <dict 0x14ebfef00>
# gc: collectable <list 0x14ebfe7c0>
# gc: collectable <list 0x14ebfec00>
# gc: collectable <list 0x14ec040c0>
# gc: collectable <cell 0x11f3efe20>
# gc: collectable <cell 0x13e78c070>
# gc: collectable <cell 0x13e7b2430>
# gc: collectable <cell 0x14e9c8310>
# gc: collectable <cell 0x14e9c8340>
# gc: collectable <tuple 0x13f574900>
# gc: collectable <function 0x14ebfc1f0>
# gc: collectable <dict 0x14ebf8780>
# gc: collectable <list 0x14ebfe940>
# gc: collectable <list 0x14ebfefc0>
# gc: collectable <dict 0x14ebfe5c0>
# gc: collectable <AppFuture 0x14e9c84c0>
# gc: collectable <Condition 0x14e9c8400>
# gc: collectable <builtin_function_or_method 0x14ebff220>
# gc: collectable <dict 0x14ebfebc0>
# gc: collectable <builtin_function_or_method 0x14ebff720>
# gc: collectable <builtin_function_or_method 0x14ebff770>
# gc: collectable <builtin_function_or_method 0x14ebff950>
# gc: collectable <builtin_function_or_method 0x14ebff9a0>
# gc: collectable <collections.deque 0x14ebb9880>
# gc: collectable <dict 0x14ebfec80>
# gc: collectable <list 0x14ec04040>
# gc: collectable <list 0x14ec041c0>
# gc: collectable <list 0x14ec04200>
# gc: collectable <list 0x14ec04240>
# gc: collectable <method 0x14ebfea00>
# gc: collectable <functools.partial 0x14ebffa40>
# gc: collectable <tuple 0x13ea2b130>
# gc: collectable <list 0x14ec04400>
# gc: collectable <Future 0x14ea0c370>
# gc: collectable <Condition 0x14ea0cfd0>
# gc: collectable <builtin_function_or_method 0x14ebffa90>
# gc: collectable <dict 0x14ec044c0>
# gc: collectable <builtin_function_or_method 0x14ebffc20>
# gc: collectable <builtin_function_or_method 0x14ebffc70>
# gc: collectable <builtin_function_or_method 0x14ebffcc0>
# gc: collectable <builtin_function_or_method 0x14ebffd10>
# gc: collectable <collections.deque 0x14ebad520>
# gc: collectable <dict 0x14ec04500>
# gc: collectable <list 0x14ec04480>
# gc: collectable <list 0x14ec04540>
# gc: collectable <method 0x14ec04440>
# gc: collectable <functools.partial 0x14ebffae0>
# gc: collectable <tuple 0x13e85e3a0>
# gc: collectable <list 0x14ebf4c80>
# gc: collectable <dict 0x14ec045c0>
# gc: collectable <dict 0x14ec04380>
# gc: collectable <list 0x14ec04140>
# gc: collectable <list 0x14ec04180>
# gc: collectable <dict 0x14ebf4f40>
# gc: collectable <AppFuture 0x13e84d6d0>
# gc: collectable <Condition 0x13e84d640>
# gc: collectable <builtin_function_or_method 0x14ebffb80>
# gc: collectable <dict 0x14ebfee40>
# gc: collectable <builtin_function_or_method 0x14ebffb30>
# gc: collectable <builtin_function_or_method 0x14ebffbd0>
# gc: collectable <builtin_function_or_method 0x14ebffdb0>
# gc: collectable <builtin_function_or_method 0x14ebffe00>
# gc: collectable <collections.deque 0x14ebe8940>
# gc: collectable <dict 0x14ec04600>
# gc: collectable <list 0x14ec04780>
# gc: collectable <list 0x14ec04700>
# gc: collectable <list 0x14ec04640>
# gc: collectable <list 0x14ec04880>
# gc: collectable <method 0x14ec048c0>
# gc: collectable <functools.partial 0x14ebffea0>
# gc: collectable <tuple 0x13f5a03a0>
# gc: collectable <list 0x14ec04940>
# gc: collectable <Future 0x13e84d5b0>
# gc: collectable <Condition 0x13e84d580>
# gc: collectable <builtin_function_or_method 0x14ebffef0>
# gc: collectable <dict 0x14ec04a80>
# gc: collectable <builtin_function_or_method 0x14ec050e0>
# gc: collectable <builtin_function_or_method 0x14ec05130>
# gc: collectable <builtin_function_or_method 0x14ec05180>
# gc: collectable <builtin_function_or_method 0x14ec051d0>
# gc: collectable <collections.deque 0x14ebe89a0>
# gc: collectable <dict 0x14ec04ac0>
# gc: collectable <list 0x14ec04a40>
# gc: collectable <list 0x14ec04b00>
# gc: collectable <method 0x14ec04a00>
# gc: collectable <functools.partial 0x14ebf9c20>
# gc: collectable <tuple 0x13eeb5a30>
# gc: collectable <list 0x14ec04800>
# gc: collectable <dict 0x14ec04b80>
# gc: collectable <dict 0x14ec04900>
# gc: collectable <list 0x14ebfef80>
# gc: collectable <list 0x14ec04840>
# gc: collectable <dict 0x14ec04580>
# gc: collectable <AppFuture 0x13e84d2e0>
# gc: collectable <Condition 0x13e84d340>
# gc: collectable <builtin_function_or_method 0x14ebfff40>
# gc: collectable <dict 0x14ec042c0>
# gc: collectable <builtin_function_or_method 0x14ec05040>
# gc: collectable <builtin_function_or_method 0x14ec05090>
# gc: collectable <builtin_function_or_method 0x14ec05270>
# gc: collectable <builtin_function_or_method 0x14ec052c0>
# gc: collectable <collections.deque 0x14ebe8a00>
# gc: collectable <dict 0x14ec04bc0>
# gc: collectable <list 0x14ec04d40>
# gc: collectable <list 0x14ec04cc0>
# gc: collectable <list 0x14ec04c00>
# gc: collectable <list 0x14ec04e40>
# gc: collectable <method 0x14ec04e80>
# gc: collectable <functools.partial 0x14ec05360>
# gc: collectable <tuple 0x13eeb5670>
# gc: collectable <list 0x14ec04f00>
# gc: collectable <Future 0x13e84df10>
# gc: collectable <Condition 0x13e84df40>
# gc: collectable <builtin_function_or_method 0x14ec053b0>
# gc: collectable <dict 0x14ec06080>
# gc: collectable <builtin_function_or_method 0x14ec05540>
# gc: collectable <builtin_function_or_method 0x14ec05590>
# gc: collectable <builtin_function_or_method 0x14ec055e0>
# gc: collectable <builtin_function_or_method 0x14ec05630>
# gc: collectable <collections.deque 0x14ebe8a60>
# gc: collectable <dict 0x14ec060c0>
# gc: collectable <list 0x14ec04f80>
# gc: collectable <list 0x14ec06100>
# gc: collectable <method 0x14ec04fc0>
# gc: collectable <functools.partial 0x14ebff1d0>
# gc: collectable <tuple 0x13f5a0460>
# gc: collectable <list 0x14ec04dc0>
# gc: collectable <dict 0x14ec06180>
# gc: collectable <dict 0x14ec04ec0>
# gc: collectable <list 0x14ec04740>
# gc: collectable <list 0x14ec04e00>
# gc: collectable <dict 0x14ec04b40>
# gc: collectable <AppFuture 0x13e84dfd0>
# gc: collectable <Condition 0x13e84d0d0>
# gc: collectable <builtin_function_or_method 0x14ec05400>
# gc: collectable <dict 0x14ec04980>
# gc: collectable <builtin_function_or_method 0x14ec05450>
# gc: collectable <builtin_function_or_method 0x14ec054f0>
# gc: collectable <builtin_function_or_method 0x14ec056d0>
# gc: collectable <builtin_function_or_method 0x14ec05720>
# gc: collectable <collections.deque 0x14ebe8ac0>
# gc: collectable <dict 0x14ec061c0>
# gc: collectable <list 0x14ec06340>
# gc: collectable <list 0x14ec062c0>
# gc: collectable <list 0x14ec06200>
# gc: collectable <list 0x14ec06440>
# gc: collectable <method 0x14ec06480>
# gc: collectable <functools.partial 0x14ec057c0>
# gc: collectable <tuple 0x14e9c89a0>
# gc: collectable <list 0x14ec06500>
# gc: collectable <Future 0x13e84db80>
# gc: collectable <Condition 0x13e84db50>
# gc: collectable <builtin_function_or_method 0x14ec05810>
# gc: collectable <dict 0x14ec06640>
# gc: collectable <builtin_function_or_method 0x14ec059a0>
# gc: collectable <builtin_function_or_method 0x14ec059f0>
# gc: collectable <builtin_function_or_method 0x14ec05a40>
# gc: collectable <builtin_function_or_method 0x14ec05a90>
# gc: collectable <collections.deque 0x14ebe8b20>
# gc: collectable <dict 0x14ec06680>
# gc: collectable <list 0x14ec06600>
# gc: collectable <list 0x14ec066c0>
# gc: collectable <method 0x14ec065c0>
# gc: collectable <functools.partial 0x14ebfff90>
# gc: collectable <tuple 0x13f5588b0>
# gc: collectable <list 0x14ec063c0>
# gc: collectable <dict 0x14ec06740>
# gc: collectable <list 0x14ec06940>
# gc: collectable <list 0x14ec04d00>
# gc: collectable <dict 0x14ec06800>
# gc: collectable <list 0x14ec06300>
# gc: collectable <list 0x14ec06900>
# gc: collectable <dict 0x14ec06780>
# gc: collectable <AppFuture 0x13e84d400>
# gc: collectable <Condition 0x13e84d3d0>
# gc: collectable <builtin_function_or_method 0x14ec05860>
# gc: collectable <dict 0x14ec06280>
# gc: collectable <builtin_function_or_method 0x14ec058b0>
# gc: collectable <builtin_function_or_method 0x14ec05950>
# gc: collectable <builtin_function_or_method 0x14ec05b30>
# gc: collectable <builtin_function_or_method 0x14ec05b80>
# gc: collectable <collections.deque 0x14ebe8b80>
# gc: collectable <dict 0x14ec04f40>
# gc: collectable <list 0x14ec067c0>
# gc: collectable <list 0x14ec069c0>
# gc: collectable <list 0x14ec06a40>
# gc: collectable <list 0x14ec06a80>
# gc: collectable <method 0x14ec06ac0>
# gc: collectable <functools.partial 0x14ec05c20>
# gc: collectable <tuple 0x14ea21490>
# gc: collectable <list 0x14ec06b80>
# gc: collectable <Future 0x13e84d820>
# gc: collectable <Condition 0x13e84d850>
# gc: collectable <builtin_function_or_method 0x14ec05d10>
# gc: collectable <dict 0x14ec06d00>
# gc: collectable <builtin_function_or_method 0x14ec05e50>
# gc: collectable <builtin_function_or_method 0x14ec05ea0>
# gc: collectable <builtin_function_or_method 0x14ec05ef0>
# gc: collectable <builtin_function_or_method 0x14ec05f40>
# gc: collectable <collections.deque 0x14ebe8be0>
# gc: collectable <dict 0x14ec06d40>
# gc: collectable <list 0x14ec06c80>
# gc: collectable <list 0x14ec06d80>
# gc: collectable <method 0x14ec06c40>
# gc: collectable <functools.partial 0x14ec05cc0>
# gc: collectable <tuple 0x14ea0ce50>
# gc: collectable <dict 0x14ec06b00>
# gc: collectable <cell 0x13e84d460>
# gc: collectable <cell 0x13e84d4c0>
# gc: collectable <list 0x14ec06400>
# gc: collectable <list 0x14ec06a00>
# gc: collectable <dict 0x14ec06b40>
# gc: collectable <AppFuture 0x13e84d9d0>
# gc: collectable <Condition 0x13e84d9a0>
# gc: collectable <builtin_function_or_method 0x14ec05d60>
# gc: collectable <dict 0x14ec06e40>
# gc: collectable <builtin_function_or_method 0x14ec05c70>
# gc: collectable <builtin_function_or_method 0x14ec05db0>
# gc: collectable <builtin_function_or_method 0x14ec05e00>
# gc: collectable <builtin_function_or_method 0x14ec08040>
# gc: collectable <collections.deque 0x14ebe8c40>
# gc: collectable <dict 0x14ec06e80>
# gc: collectable <list 0x14ec06e00>
# gc: collectable <list 0x14ec06ec0>
# gc: collectable <list 0x14ec09040>
# gc: collectable <list 0x14ec06f40>
# gc: collectable <method 0x14ec09140>
# gc: collectable <functools.partial 0x14ec08220>
# gc: collectable <tuple 0x13e85e3d0>
# gc: collectable <tuple 0x1190fa8c0>
# gc: collectable <function 0x14ebfc700>
# gc: collectable <tuple 0x14e9d5100>
# gc: collectable <cython_function_or_method 0x14ec152b0>
# gc: collectable <cython_function_or_method 0x14ec15380>
# gc: collectable <cython_function_or_method 0x14ec15450>
# gc: collectable <dict 0x14ec3c340>
# gc: collectable <pyarrow._fs.__Pyx_EnumMeta 0x11d107ec0>
# gc: collectable <getset_descriptor 0x14ec10a00>
# gc: collectable <tuple 0x14ec27280>
# gc: collectable <collections.OrderedDict 0x14ec2a7c0>
# gc: collectable <tuple 0x13f558850>
# gc: collectable <cython_function_or_method 0x14ec15ad0>
# gc: collectable <cython_function_or_method 0x14ec15ba0>
# gc: collectable <cython_function_or_method 0x14ec15c70>
# gc: collectable <dict 0x14ec4c540>
# gc: collectable <pyarrow._s3fs.__Pyx_EnumMeta 0x11c50c990>
# gc: collectable <getset_descriptor 0x11c298100>
# gc: collectable <tuple 0x14ec3ca40>
# gc: collectable <collections.OrderedDict 0x14ec2aa40>
# gc: collectable <list 0x14ec1e8c0>
# gc: collectable <Future 0x13e84de20>
# gc: collectable <Condition 0x13e84d1f0>
# gc: collectable <builtin_function_or_method 0x14ec196d0>
# gc: collectable <dict 0x14ec09300>
# gc: collectable <builtin_function_or_method 0x14ec369f0>
# gc: collectable <builtin_function_or_method 0x14ec21bd0>
# gc: collectable <builtin_function_or_method 0x14ec21c20>
# gc: collectable <builtin_function_or_method 0x14ec21c70>
# gc: collectable <collections.deque 0x14ecc8b80>
# gc: collectable <dict 0x14ec09340>
# gc: collectable <list 0x14ec1e940>
# gc: collectable <list 0x14ec10f80>
# gc: collectable <method 0x13e3f2d40>
# gc: collectable <functools.partial 0x14ec080e0>
# gc: collectable <tuple 0x14ea0c880>
# gc: collectable <dict 0x14ec068c0>
# gc: collectable <list 0x14ec23240>
# gc: collectable <list 0x14ec5e9c0>
# gc: collectable <dict 0x14ec06dc0>
# gc: collectable <list 0x14ec23440>
# gc: collectable <list 0x14ec61ac0>
# gc: collectable <dict 0x14ec09680>
# gc: collectable <AppFuture 0x13e84da30>
# gc: collectable <Condition 0x13e84dc40>
# gc: collectable <builtin_function_or_method 0x14ec505e0>
# gc: collectable <dict 0x14ec09100>
# gc: collectable <builtin_function_or_method 0x14ec50310>
# gc: collectable <builtin_function_or_method 0x14ecb12c0>
# gc: collectable <builtin_function_or_method 0x14ecb1680>
# gc: collectable <builtin_function_or_method 0x14ecb1630>
# gc: collectable <collections.deque 0x14ecb0160>
# gc: collectable <dict 0x14ec091c0>
# gc: collectable <list 0x14ec1e7c0>
# gc: collectable <list 0x14ec1e6c0>
# gc: collectable <list 0x14ec1e600>
# gc: collectable <list 0x13e3f2c80>
# gc: collectable <method 0x14ec5f300>
# gc: collectable <functools.partial 0x14ecb1720>
# gc: collectable <tuple 0x13ee891f0>
# gc: collectable <list 0x14ec1e580>
# gc: collectable <Future 0x13ec719a0>
# gc: collectable <Condition 0x14e9c7130>
# gc: collectable <builtin_function_or_method 0x14ecb1810>
# gc: collectable <dict 0x14ec1da40>
# gc: collectable <builtin_function_or_method 0x14ecb1950>
# gc: collectable <builtin_function_or_method 0x14ecb19a0>
# gc: collectable <builtin_function_or_method 0x14ecb19f0>
# gc: collectable <builtin_function_or_method 0x14ecb1a40>
# gc: collectable <collections.deque 0x14ecb01c0>
# gc: collectable <dict 0x14ece2480>
# gc: collectable <list 0x14ec1e540>
# gc: collectable <list 0x14ec1e4c0>
# gc: collectable <method 0x13e7f7240>
# gc: collectable <functools.partial 0x14ecb17c0>
# gc: collectable <tuple 0x13f5580d0>
# gc: collectable <dict 0x14ec09240>
# gc: collectable <cell 0x13e84d2b0>
# gc: collectable <cell 0x13e84dbe0>
# gc: collectable <list 0x14ec1e700>
# gc: collectable <list 0x14ec1e640>
# gc: collectable <dict 0x14ec60700>
# gc: collectable <AppFuture 0x14e9c7d00>
# gc: collectable <Condition 0x14e9c7d30>
# gc: collectable <builtin_function_or_method 0x14ecb1860>
# gc: collectable <dict 0x14ece2a40>
# gc: collectable <builtin_function_or_method 0x14ecb1770>
# gc: collectable <builtin_function_or_method 0x14ecb18b0>
# gc: collectable <builtin_function_or_method 0x14ecb1900>
# gc: collectable <builtin_function_or_method 0x14ecb1ae0>
# gc: collectable <collections.deque 0x14ecb0220>
# gc: collectable <dict 0x14ece2980>
# gc: collectable <list 0x14ec1e480>
# gc: collectable <list 0x14ec1e400>
# gc: collectable <list 0x14ec1e300>
# gc: collectable <list 0x11c298ac0>
# gc: collectable <method 0x14ec44b80>
# gc: collectable <functools.partial 0x14ecb1c20>
# gc: collectable <tuple 0x13eeb5a60>
# gc: collectable <tuple 0x14e9b8540>
# gc: collectable <function 0x14ecce280>
# gc: collectable <list 0x14ec1e3c0>
# gc: collectable <Future 0x14e9c75b0>
# gc: collectable <Condition 0x14e9c75e0>
# gc: collectable <builtin_function_or_method 0x14ecaec70>
# gc: collectable <dict 0x14ece2f00>
# gc: collectable <builtin_function_or_method 0x14ecb1d10>
# gc: collectable <builtin_function_or_method 0x14ecb1d60>
# gc: collectable <builtin_function_or_method 0x14ecb1db0>
# gc: collectable <builtin_function_or_method 0x14ecb1e00>
# gc: collectable <collections.deque 0x14ecb0280>
# gc: collectable <dict 0x14ece2fc0>
# gc: collectable <list 0x14ec0de80>
# gc: collectable <list 0x14ec1e2c0>
# gc: collectable <method 0x14ec5f680>
# gc: collectable <functools.partial 0x14ecb1bd0>
# gc: collectable <tuple 0x13ef329a0>
# gc: collectable <dict 0x14ec5ed40>
# gc: collectable <list 0x14ec60840>
# gc: collectable <list 0x14ec1e280>
# gc: collectable <dict 0x14ece2880>
# gc: collectable <list 0x14ec1e240>
# gc: collectable <list 0x14ec1e180>
# gc: collectable <dict 0x14ecdf300>
# gc: collectable <AppFuture 0x14e9c7ca0>
# gc: collectable <Condition 0x14e9c7f70>
# gc: collectable <builtin_function_or_method 0x14ec05900>
# gc: collectable <dict 0x14ecdf400>
# gc: collectable <builtin_function_or_method 0x14ecb1cc0>
# gc: collectable <builtin_function_or_method 0x14ecb1b80>
# gc: collectable <builtin_function_or_method 0x14ecb1ea0>
# gc: collectable <builtin_function_or_method 0x14ecb1ef0>
# gc: collectable <collections.deque 0x14ecb02e0>
# gc: collectable <dict 0x14ec09440>
# gc: collectable <list 0x14ec1e100>
# gc: collectable <list 0x14ec1e0c0>
# gc: collectable <list 0x14ec23f80>
# gc: collectable <list 0x14ec10240>
# gc: collectable <method 0x14ec10080>
# gc: collectable <functools.partial 0x14ecb1f90>
# gc: collectable <tuple 0x14ecbb430>
# gc: collectable <list 0x14ec23f00>
# gc: collectable <Future 0x14e9c79a0>
# gc: collectable <Condition 0x14e9c79d0>
# gc: collectable <builtin_function_or_method 0x14ecb2090>
# gc: collectable <dict 0x14ecdf640>
# gc: collectable <builtin_function_or_method 0x14ecb21d0>
# gc: collectable <builtin_function_or_method 0x14ecb2220>
# gc: collectable <builtin_function_or_method 0x14ecb2270>
# gc: collectable <builtin_function_or_method 0x14ecb22c0>
# gc: collectable <collections.deque 0x14ecb0340>
# gc: collectable <dict 0x14ecdf7c0>
# gc: collectable <list 0x14ec23ec0>
# gc: collectable <list 0x14ec23e40>
# gc: collectable <method 0x14eccf1c0>
# gc: collectable <functools.partial 0x14ecb1c70>
# gc: collectable <tuple 0x14ec93be0>
# gc: collectable <dict 0x14ece2d00>
# gc: collectable <cell 0x14e9c7670>
# gc: collectable <cell 0x14e9c7e50>
# gc: collectable <list 0x14ec1e1c0>
# gc: collectable <list 0x14ec23fc0>
# gc: collectable <dict 0x14ecdf4c0>
# gc: collectable <AppFuture 0x14e9c7b20>
# gc: collectable <Condition 0x14e9c70a0>
# gc: collectable <builtin_function_or_method 0x14ecb2040>
# gc: collectable <dict 0x14ecd2440>
# gc: collectable <builtin_function_or_method 0x14ecb20e0>
# gc: collectable <builtin_function_or_method 0x14ecb2130>
# gc: collectable <builtin_function_or_method 0x14ecb2180>
# gc: collectable <builtin_function_or_method 0x14ecb2360>
# gc: collectable <collections.deque 0x14ecb03a0>
# gc: collectable <dict 0x14ecd24c0>
# gc: collectable <list 0x14ec23e00>
# gc: collectable <list 0x14ec23d80>
# gc: collectable <list 0x14ec23c40>
# gc: collectable <list 0x14eccff80>
# gc: collectable <method 0x14eccff00>
# gc: collectable <functools.partial 0x14ecb2400>
# gc: collectable <tuple 0x14ec93bb0>
# gc: collectable <tuple 0x13f5a58c0>
# gc: collectable <function 0x14ecaff70>
# gc: collectable <list 0x14eccf3c0>
# gc: collectable <Future 0x14e9c78b0>
# gc: collectable <Condition 0x13e6e77c0>
# gc: collectable <builtin_function_or_method 0x14ec054a0>
# gc: collectable <dict 0x14ece2e00>
# gc: collectable <builtin_function_or_method 0x14ecb25e0>
# gc: collectable <builtin_function_or_method 0x14ecb2630>
# gc: collectable <builtin_function_or_method 0x14ecb2680>
# gc: collectable <builtin_function_or_method 0x14ecb26d0>
# gc: collectable <collections.deque 0x14ecb0400>
# gc: collectable <dict 0x14ecdf140>
# gc: collectable <list 0x14ec23c80>
# gc: collectable <list 0x14ec23d40>
# gc: collectable <method 0x11f0f7f00>
# gc: collectable <functools.partial 0x14ecb24f0>
# gc: collectable <tuple 0x14ec939d0>
# gc: collectable <dict 0x14ecd42c0>
# gc: collectable <list 0x14ec104c0>
# gc: collectable <list 0x14ec23b80>
# gc: collectable <dict 0x14ecdf8c0>
# gc: collectable <list 0x14ec23b40>
# gc: collectable <list 0x14ec23a40>
# gc: collectable <dict 0x14ecd2600>
# gc: collectable <AppFuture 0x13e6e7cd0>
# gc: collectable <Condition 0x13e6e7fd0>
# gc: collectable <builtin_function_or_method 0x14ecb2450>
# gc: collectable <dict 0x14ecd2740>
# gc: collectable <builtin_function_or_method 0x14ecb2540>
# gc: collectable <builtin_function_or_method 0x14ecb2590>
# gc: collectable <builtin_function_or_method 0x14ecb2770>
# gc: collectable <builtin_function_or_method 0x14ecb27c0>
# gc: collectable <collections.deque 0x14ecb0460>
# gc: collectable <dict 0x14ecd2640>
# gc: collectable <list 0x14ec239c0>
# gc: collectable <list 0x14ec23980>
# gc: collectable <list 0x14ec23900>
# gc: collectable <list 0x14ec61380>
# gc: collectable <method 0x14ec61140>
# gc: collectable <functools.partial 0x14ecb2860>
# gc: collectable <tuple 0x14ec939a0>
# gc: collectable <list 0x14ec23880>
# gc: collectable <Future 0x13e6e78b0>
# gc: collectable <Condition 0x13e6e7b80>
# gc: collectable <builtin_function_or_method 0x14ecb2950>
# gc: collectable <dict 0x14ecd2c00>
# gc: collectable <builtin_function_or_method 0x14ecb2a90>
# gc: collectable <builtin_function_or_method 0x14ecb2ae0>
# gc: collectable <builtin_function_or_method 0x14ecb2b30>
# gc: collectable <builtin_function_or_method 0x14ecb2b80>
# gc: collectable <collections.deque 0x14ecb04c0>
# gc: collectable <dict 0x14ecd2bc0>
# gc: collectable <list 0x14ec23840>
# gc: collectable <list 0x14ec237c0>
# gc: collectable <method 0x14ec61340>
# gc: collectable <functools.partial 0x14ecb2900>
# gc: collectable <tuple 0x14ec93640>
# gc: collectable <dict 0x14ecd2680>
# gc: collectable <cell 0x14e9c77f0>
# gc: collectable <cell 0x14e9c7790>
# gc: collectable <list 0x14ec23a80>
# gc: collectable <list 0x14ec23940>
# gc: collectable <dict 0x14ecd2800>
# gc: collectable <AppFuture 0x13e6e7820>
# gc: collectable <Condition 0x13e6e7c40>
# gc: collectable <builtin_function_or_method 0x14ecb29a0>
# gc: collectable <dict 0x14ec61440>
# gc: collectable <builtin_function_or_method 0x14ecb28b0>
# gc: collectable <builtin_function_or_method 0x14ecb29f0>
# gc: collectable <builtin_function_or_method 0x14ecb2a40>
# gc: collectable <builtin_function_or_method 0x14ecb2c20>
# gc: collectable <collections.deque 0x14ecb0520>
# gc: collectable <dict 0x14ec613c0>
# gc: collectable <list 0x14ec23780>
# gc: collectable <list 0x14ec23700>
# gc: collectable <list 0x14ec23600>
# gc: collectable <list 0x14ec61540>
# gc: collectable <method 0x14ec616c0>
# gc: collectable <functools.partial 0x14ecb2d60>
# gc: collectable <tuple 0x14ec93850>
# gc: collectable <tuple 0x14ebf4880>
# gc: collectable <function 0x14ecb4040>
# gc: collectable <list 0x14ec236c0>
# gc: collectable <Future 0x13e6e7a00>
# gc: collectable <Condition 0x13e6e7790>
# gc: collectable <builtin_function_or_method 0x14ec08180>
# gc: collectable <dict 0x14ec61680>
# gc: collectable <builtin_function_or_method 0x14ecb2ea0>
# gc: collectable <builtin_function_or_method 0x14ecb2ef0>
# gc: collectable <builtin_function_or_method 0x14ecb2f40>
# gc: collectable <builtin_function_or_method 0x14ecb2f90>
# gc: collectable <collections.deque 0x14ecb0580>
# gc: collectable <dict 0x14ec61800>
# gc: collectable <list 0x14ec61040>
# gc: collectable <list 0x14ec235c0>
# gc: collectable <method 0x14ecc13c0>
# gc: collectable <functools.partial 0x14ecb2db0>
# gc: collectable <tuple 0x14ec93790>
# gc: collectable <dict 0x14ecc1700>
# gc: collectable <dict 0x14ecd2d00>
# gc: collectable <list 0x14ec23540>
# gc: collectable <list 0x14ec23380>
# gc: collectable <dict 0x14eccfe80>
# gc: collectable <AppFuture 0x13e6e7ee0>
# gc: collectable <Condition 0x13e6e7a30>
# gc: collectable <builtin_function_or_method 0x14ecb2e00>
# gc: collectable <dict 0x14ecc1340>
# gc: collectable <builtin_function_or_method 0x14ecb2cc0>
# gc: collectable <builtin_function_or_method 0x14ecb2e50>
# gc: collectable <builtin_function_or_method 0x14ecb5090>
# gc: collectable <builtin_function_or_method 0x14ecb50e0>
# gc: collectable <collections.deque 0x14ecb05e0>
# gc: collectable <dict 0x14ecd2780>
# gc: collectable <list 0x14ec23500>
# gc: collectable <list 0x14ec23200>
# gc: collectable <list 0x14ec23100>
# gc: collectable <list 0x14ecc17c0>
# gc: collectable <method 0x14ecc1740>
# gc: collectable <functools.partial 0x14ecb5180>
# gc: collectable <tuple 0x13f3c7790>
# gc: collectable <list 0x14ec23080>
# gc: collectable <Future 0x13e6e7b50>
# gc: collectable <Condition 0x13e6e7ac0>
# gc: collectable <builtin_function_or_method 0x14ecb51d0>
# gc: collectable <dict 0x14ecc1500>
# gc: collectable <builtin_function_or_method 0x14ecb5360>
# gc: collectable <builtin_function_or_method 0x14ecb53b0>
# gc: collectable <builtin_function_or_method 0x14ecb5400>
# gc: collectable <builtin_function_or_method 0x14ecb5450>
# gc: collectable <collections.deque 0x14ecb0640>
# gc: collectable <dict 0x14ecc1600>
# gc: collectable <list 0x14ec23040>
# gc: collectable <list 0x14ecdaf40>
# gc: collectable <method 0x14ecc1780>
# gc: collectable <functools.partial 0x14ecb5220>
# gc: collectable <tuple 0x14ec93520>
# gc: collectable <pyarrow._parquet.FileMetaData 0x14ecb5270>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x14ec617c0>
# gc: collectable <pyarrow._parquet.FileMetaData 0x14ecb5f40>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x14ec8d040>
# gc: collectable <PosixPath 0x14ec90ee0>
# gc: collectable <list 0x14ecb8180>
# gc: collectable <dict 0x14ecc1840>
# gc: collectable <list 0x14ecb8080>
# gc: collectable <PosixPath 0x14ec90e80>
# gc: collectable <list 0x14ecb8200>
# gc: collectable <list 0x14ecb8280>
# gc: collectable <dict 0x14ec06700>
# gc: collectable <dict 0x14ec61640>
# gc: collectable <list 0x14ecb8100>
# gc: collectable <list 0x14ecb8380>
# gc: collectable <dict 0x13e3f2f80>
# gc: collectable <AppFuture 0x13e6e7b20>
# gc: collectable <Condition 0x13e6e7e50>
# gc: collectable <builtin_function_or_method 0x14ecb5540>
# gc: collectable <dict 0x14ec8d440>
# gc: collectable <builtin_function_or_method 0x14ecb55e0>
# gc: collectable <builtin_function_or_method 0x14ecb5630>
# gc: collectable <builtin_function_or_method 0x14ecb5680>
# gc: collectable <builtin_function_or_method 0x14ecb56d0>
# gc: collectable <collections.deque 0x14ecb06a0>
# gc: collectable <dict 0x14ec615c0>
# gc: collectable <list 0x14ecb8400>
# gc: collectable <list 0x14ecb8480>
# gc: collectable <list 0x14ecb8580>
# gc: collectable <list 0x14ec8d280>
# gc: collectable <method 0x14ec8d940>
# gc: collectable <functools.partial 0x14ecb5770>
# gc: collectable <tuple 0x14ec93820>
# gc: collectable <list 0x14ecb8600>
# gc: collectable <Future 0x13e6e7670>
# gc: collectable <Condition 0x13e6e7610>
# gc: collectable <builtin_function_or_method 0x14ecb57c0>
# gc: collectable <dict 0x14ec8d300>
# gc: collectable <builtin_function_or_method 0x14ecb5950>
# gc: collectable <builtin_function_or_method 0x14ecb59a0>
# gc: collectable <builtin_function_or_method 0x14ecb59f0>
# gc: collectable <builtin_function_or_method 0x14ecb5a40>
# gc: collectable <collections.deque 0x14ecb0700>
# gc: collectable <dict 0x14ec8d340>
# gc: collectable <list 0x14ecb8680>
# gc: collectable <list 0x14ecb8700>
# gc: collectable <method 0x14ec8d500>
# gc: collectable <functools.partial 0x14ecb5810>
# gc: collectable <tuple 0x14ec93760>
# gc: collectable <pyarrow._parquet.FileMetaData 0x14ecb5900>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x14ec97040>
# gc: collectable <pyarrow._parquet.FileMetaData 0x14ec9aef0>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x14ec8b580>
# gc: collectable <PosixPath 0x14ec88100>
# gc: collectable <list 0x14ec92680>
# gc: collectable <dict 0x14ec8d400>
# gc: collectable <list 0x14ec925c0>
# gc: collectable <PosixPath 0x14ec880a0>
# gc: collectable <list 0x14ec92700>
# gc: collectable <list 0x14ec92740>
# gc: collectable <dict 0x14ecc1680>
# gc: collectable <list 0x14ec92600>
# gc: collectable <list 0x14ec927c0>
# gc: collectable <dict 0x14ec8d1c0>
# gc: collectable <AppFuture 0x13e9fe130>
# gc: collectable <Condition 0x13e9fe1f0>
# gc: collectable <builtin_function_or_method 0x14ecb2d10>
# gc: collectable <dict 0x14ece2b00>
# gc: collectable <builtin_function_or_method 0x14ecbaf90>
# gc: collectable <builtin_function_or_method 0x14ecbaf40>
# gc: collectable <builtin_function_or_method 0x14ecbaef0>
# gc: collectable <builtin_function_or_method 0x14ecbaea0>
# gc: collectable <collections.deque 0x14ecb0760>
# gc: collectable <dict 0x14ec8d980>
# gc: collectable <list 0x14ec92800>
# gc: collectable <list 0x14ec92840>
# gc: collectable <list 0x14ec92940>
# gc: collectable <list 0x14ece2dc0>
# gc: collectable <method 0x14ece2cc0>
# gc: collectable <functools.partial 0x14ecbae00>
# gc: collectable <tuple 0x14ec93460>
# gc: collectable <list 0x14ec92980>
# gc: collectable <Future 0x13e9fe040>
# gc: collectable <Condition 0x13e9fe250>
# gc: collectable <builtin_function_or_method 0x14ecbadb0>
# gc: collectable <dict 0x14ece2e80>
# gc: collectable <builtin_function_or_method 0x14ecbac20>
# gc: collectable <builtin_function_or_method 0x14ecbabd0>
# gc: collectable <builtin_function_or_method 0x14ecbab80>
# gc: collectable <builtin_function_or_method 0x14ecbab30>
# gc: collectable <collections.deque 0x14ecb07c0>
# gc: collectable <dict 0x14ece2c80>
# gc: collectable <list 0x14ec929c0>
# gc: collectable <list 0x14ec92a00>
# gc: collectable <method 0x14ece2c40>
# gc: collectable <functools.partial 0x14ecbad60>
# gc: collectable <tuple 0x14ec93400>
# gc: collectable <pyarrow._parquet.FileMetaData 0x14ecbac70>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x14ec92780>
# gc: collectable <pyarrow._parquet.FileMetaData 0x14ec95ef0>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x14ec610c0>
# gc: collectable <PosixPath 0x14ec8e880>
# gc: collectable <list 0x14ec97900>
# gc: collectable <dict 0x14ece2280>
# gc: collectable <list 0x14ec97980>
# gc: collectable <PosixPath 0x14ec8e820>
# gc: collectable <list 0x14ec978c0>
# gc: collectable <list 0x14ec97880>
# gc: collectable <dict 0x14ec8d2c0>
# gc: collectable <list 0x14ec97940>
# gc: collectable <list 0x14ec97800>
# gc: collectable <dict 0x14ece2680>
# gc: collectable <AppFuture 0x13e9fe580>
# gc: collectable <Condition 0x13e9fe520>
# gc: collectable <builtin_function_or_method 0x14ec9af90>
# gc: collectable <dict 0x14ec61840>
# gc: collectable <builtin_function_or_method 0x14ec9ab80>
# gc: collectable <builtin_function_or_method 0x14ec9aae0>
# gc: collectable <builtin_function_or_method 0x14ec9abd0>
# gc: collectable <builtin_function_or_method 0x14ec9ac20>
# gc: collectable <collections.deque 0x14ecb0820>
# gc: collectable <dict 0x14ece2400>
# gc: collectable <list 0x14ec977c0>
# gc: collectable <list 0x14ec97780>
# gc: collectable <list 0x14ec97700>
# gc: collectable <list 0x14ec619c0>
# gc: collectable <method 0x14ec61900>
# gc: collectable <functools.partial 0x14ec9acc0>
# gc: collectable <tuple 0x14ec933a0>
# gc: collectable <list 0x14ec976c0>
# gc: collectable <Future 0x13e9fe2e0>
# gc: collectable <Condition 0x13e9fe0d0>
# gc: collectable <builtin_function_or_method 0x14ec9ad10>
# gc: collectable <dict 0x14ec61ec0>
# gc: collectable <builtin_function_or_method 0x14ec9aea0>
# gc: collectable <builtin_function_or_method 0x14ec9af40>
# gc: collectable <builtin_function_or_method 0x14ecb5590>
# gc: collectable <builtin_function_or_method 0x14ecb5ae0>
# gc: collectable <collections.deque 0x14ecb0880>
# gc: collectable <dict 0x14ec61940>
# gc: collectable <list 0x14ec97680>
# gc: collectable <list 0x14ec97640>
# gc: collectable <method 0x14ec61780>
# gc: collectable <functools.partial 0x14ec9ad60>
# gc: collectable <tuple 0x13f39da30>
# gc: collectable <pyarrow._parquet.FileMetaData 0x14ec9adb0>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x14ec97840>
# gc: collectable <pyarrow._parquet.FileMetaData 0x14ecbacc0>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x14ec8b1c0>
# gc: collectable <PosixPath 0x14ec8ad00>
# gc: collectable <list 0x14ecc1f00>
# gc: collectable <dict 0x14ec61fc0>
# gc: collectable <list 0x14ecc1dc0>
# gc: collectable <PosixPath 0x14ec8aca0>
# gc: collectable <list 0x14ecc1f40>
# gc: collectable <list 0x14ecc1f80>
# gc: collectable <dict 0x14ec61f80>
# gc: collectable <list 0x14ecc1ec0>
# gc: collectable <list 0x14ecc14c0>
# gc: collectable <dict 0x14ece2d80>
# gc: collectable <AppFuture 0x13eead5e0>
# gc: collectable <Condition 0x13eead2e0>
# gc: collectable <builtin_function_or_method 0x14ebff6d0>
# gc: collectable <dict 0x14ec61500>
# gc: collectable <builtin_function_or_method 0x14ec9ae00>
# gc: collectable <builtin_function_or_method 0x14ecb5b80>
# gc: collectable <builtin_function_or_method 0x14ecb5bd0>
# gc: collectable <builtin_function_or_method 0x14ecb5c20>
# gc: collectable <collections.deque 0x14ecb08e0>
# gc: collectable <dict 0x14ec61d40>
# gc: collectable <list 0x14ecc1640>
# gc: collectable <list 0x14ecc1480>
# gc: collectable <list 0x14ecc1940>
# gc: collectable <list 0x14ece2a00>
# gc: collectable <method 0x14ece2ec0>
# gc: collectable <functools.partial 0x14ecb5cc0>
# gc: collectable <tuple 0x13e9fe430>
# gc: collectable <list 0x14ecc18c0>
# gc: collectable <Future 0x13eead6a0>
# gc: collectable <Condition 0x13eead6d0>
# gc: collectable <builtin_function_or_method 0x14ecb5d10>
# gc: collectable <dict 0x14ece2740>
# gc: collectable <builtin_function_or_method 0x14ecb5ea0>
# gc: collectable <builtin_function_or_method 0x14ecb5ef0>
# gc: collectable <builtin_function_or_method 0x14ecb5f90>
# gc: collectable <builtin_function_or_method 0x14ecb58b0>
# gc: collectable <collections.deque 0x14ecb0940>
# gc: collectable <dict 0x14ec8b240>
# gc: collectable <list 0x14ecc1900>
# gc: collectable <list 0x14ecc1a00>
# gc: collectable <method 0x14ece29c0>
# gc: collectable <functools.partial 0x14ecb5d60>
# gc: collectable <tuple 0x13e9fe370>
# gc: collectable <list 0x1295e1ec0>
# gc: collectable <list 0x14ecc1fc0>
# gc: collectable <list 0x14ece2940>
# gc: collectable <dict 0x14ebf8740>
# gc: collectable <list 0x14ecc1880>
# gc: collectable <list 0x14ecc1a40>
# gc: collectable <dict 0x14ece2f80>
# gc: collectable <AppFuture 0x13eead970>
# gc: collectable <Condition 0x13eead850>
# gc: collectable <builtin_function_or_method 0x14ecb5e00>
# gc: collectable <dict 0x14ec8ba00>
# gc: collectable <builtin_function_or_method 0x14ecb5db0>
# gc: collectable <builtin_function_or_method 0x14ecb5e50>
# gc: collectable <builtin_function_or_method 0x14ec95040>
# gc: collectable <builtin_function_or_method 0x14ec95090>
# gc: collectable <collections.deque 0x14ecb09a0>
# gc: collectable <dict 0x14ec61b40>
# gc: collectable <list 0x14ecc1ac0>
# gc: collectable <list 0x14ecc1b00>
# gc: collectable <list 0x14ec92900>
# gc: collectable <list 0x14ec8ba80>
# gc: collectable <method 0x14ec8ba40>
# gc: collectable <functools.partial 0x14ec95130>
# gc: collectable <tuple 0x13e9fe310>
# gc: collectable <list 0x14ec92540>
# gc: collectable <Future 0x13eead700>
# gc: collectable <Condition 0x13eead190>
# gc: collectable <builtin_function_or_method 0x14ec95270>
# gc: collectable <dict 0x14ecdd3c0>
# gc: collectable <builtin_function_or_method 0x14ec95360>
# gc: collectable <builtin_function_or_method 0x14ec953b0>
# gc: collectable <builtin_function_or_method 0x14ec95400>
# gc: collectable <builtin_function_or_method 0x14ec95450>
# gc: collectable <collections.deque 0x14ecb0a00>
# gc: collectable <dict 0x14ecdd340>
# gc: collectable <list 0x14ec92580>
# gc: collectable <list 0x14ec92500>
# gc: collectable <method 0x14ecdd400>
# gc: collectable <functools.partial 0x14ec9ae50>
# gc: collectable <tuple 0x13eead4f0>
# gc: collectable <dict 0x14ec97a40>
# gc: collectable <list 0x14ec92400>
# gc: collectable <list 0x14ecc1980>
# gc: collectable <dict 0x14ec97a80>
# gc: collectable <AppFuture 0x13eeadfa0>
# gc: collectable <Condition 0x13eeadb80>
# gc: collectable <builtin_function_or_method 0x14ecbaa90>
# gc: collectable <dict 0x14ec97b00>
# gc: collectable <builtin_function_or_method 0x14ecba9f0>
# gc: collectable <builtin_function_or_method 0x14ecba9a0>
# gc: collectable <builtin_function_or_method 0x14ecba950>
# gc: collectable <builtin_function_or_method 0x14ecba900>
# gc: collectable <collections.deque 0x14ec8afa0>
# gc: collectable <dict 0x14ec97ac0>
# gc: collectable <list 0x14ece2ac0>
# gc: collectable <list 0x14ec8b9c0>
# gc: collectable <list 0x14ec923c0>
# gc: collectable <list 0x14ec8d240>
# gc: collectable <method 0x14ecdd680>
# gc: collectable <functools.partial 0x14ecba040>
# gc: collectable <tuple 0x13eead880>
# gc: collectable <list 0x14ec92380>
# gc: collectable <Future 0x13eeadcd0>
# gc: collectable <Condition 0x13eeadd00>
# gc: collectable <builtin_function_or_method 0x14ecba090>
# gc: collectable <dict 0x14ec97c80>
# gc: collectable <builtin_function_or_method 0x14ecb6860>
# gc: collectable <builtin_function_or_method 0x14ecb6040>
# gc: collectable <builtin_function_or_method 0x14ecb6090>
# gc: collectable <builtin_function_or_method 0x14ecb60e0>
# gc: collectable <collections.deque 0x14ec8af40>
# gc: collectable <dict 0x14ec97cc0>
# gc: collectable <list 0x14ec92340>
# gc: collectable <list 0x14ec92300>
# gc: collectable <method 0x14ecdd280>
# gc: collectable <functools.partial 0x14ecba0e0>
# gc: collectable <tuple 0x13eead1f0>
# gc: collectable <pyarrow._parquet.FileMetaData 0x14ecba130>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x14ec6afc0>
# gc: collectable <list 0x14ec6ec00>
# gc: collectable <list 0x14ec6ec40>
# gc: collectable <dict 0x14ec979c0>
# gc: collectable <AppFuture 0x13eeadd90>
# gc: collectable <Condition 0x13eeade50>
# gc: collectable <builtin_function_or_method 0x14ec64ea0>
# gc: collectable <dict 0x14ec97bc0>
# gc: collectable <builtin_function_or_method 0x14ec64f90>
# gc: collectable <builtin_function_or_method 0x14ec64f40>
# gc: collectable <builtin_function_or_method 0x14ec64ef0>
# gc: collectable <builtin_function_or_method 0x14ec64e50>
# gc: collectable <collections.deque 0x14ec905e0>
# gc: collectable <dict 0x14ec97dc0>
# gc: collectable <list 0x14ec6ec80>
# gc: collectable <list 0x14ec6ecc0>
# gc: collectable <list 0x14ec6ed40>
# gc: collectable <list 0x1295dfbc0>
# gc: collectable <method 0x14ec92280>
# gc: collectable <functools.partial 0x14ec64c20>
# gc: collectable <tuple 0x13eead760>
# gc: collectable <list 0x14ec6ed80>
# gc: collectable <Future 0x13eead3a0>
# gc: collectable <Condition 0x13eead400>
# gc: collectable <builtin_function_or_method 0x14ec64bd0>
# gc: collectable <dict 0x14ec97e40>
# gc: collectable <builtin_function_or_method 0x14ec64a40>
# gc: collectable <builtin_function_or_method 0x14ec649f0>
# gc: collectable <builtin_function_or_method 0x14ec649a0>
# gc: collectable <builtin_function_or_method 0x14ec64950>
# gc: collectable <collections.deque 0x14ec90580>
# gc: collectable <dict 0x14ec97f00>
# gc: collectable <list 0x14ec6edc0>
# gc: collectable <list 0x14ec6ee00>
# gc: collectable <method 0x14ec92440>
# gc: collectable <functools.partial 0x14ec64b80>
# gc: collectable <tuple 0x13eeade80>
# gc: collectable <method 0x14ec44180>
# gc: collectable <functools.partial 0x14ec64b30>
# gc: collectable <tuple 0x13eeaddf0>
#            id                                        type  refcount  \
# 0  5613734528                              <class 'list'>        10
# 1  5357606720                              <class 'list'>         4
# 2  5613836800                              <class 'dict'>         7
# 3  5351143936  <class 'parsl.dataflow.futures.AppFuture'>         4
# 4  5351144752               <class 'threading.Condition'>         4
#
#                                                 repr  size
# 0                                                 []    56
# 1                                                 []    56
# 2  {'depends': [], 'executor': '_parsl_internal',...  1176
# 3  <AppFuture at 0x13ef3fa00 state=finished retur...    48
# 4  <Condition(<unlocked _thread.RLock object owne...    48

# %%
# create a list of files to reference
list_of_sqlite_files = [
    "../examples/data/all_cellprofiler.sqlite",
]

# %%
cytotable.convert(
    source_path="../examples/data/all_cellprofiler.sqlite",
    dest_path="./examples/data/test-result.parquet",
    dest_datatype="parquet",
    preset="cellprofiler_sqlite_pycytominer",
)

# %%
collected = gc.collect()
if gc.garbage:
    print(f"Memory leak detected: {len(gc.garbage)} objects")
    df = pd.DataFrame(
        [
            {
                "id": id(obj),
                "type": type(obj),
                "refcount": sys.getrefcount(obj),
                "repr": repr(obj),
                "size": sys.getsizeof(obj),
            }
            for obj in gc.garbage
        ]
    )

df.head()
# Out:
# Memory leak detected: 2232 objects
# gc: collectable <cell 0x10770caf0>
# gc: collectable <tuple 0x13eead280>
# gc: collectable <function 0x110033790>
# gc: collectable <cell 0x107705bb0>
# gc: collectable <tuple 0x13efedc40>
# gc: collectable <function 0x1075b5d30>
# gc: collectable <list 0x11007f900>
# gc: collectable <list 0x13f3b9dc0>
# gc: collectable <dict 0x14eaaa9c0>
# gc: collectable <AppFuture 0x1075b60d0>
# gc: collectable <Condition 0x1075b6400>
# gc: collectable <builtin_function_or_method 0x14ecaeb30>
# gc: collectable <dict 0x14eab0340>
# gc: collectable <builtin_function_or_method 0x10757dd60>
# gc: collectable <builtin_function_or_method 0x1077205e0>
# gc: collectable <builtin_function_or_method 0x107720680>
# gc: collectable <builtin_function_or_method 0x1077206d0>
# gc: collectable <collections.deque 0x1100944c0>
# gc: collectable <dict 0x14eccf6c0>
# gc: collectable <list 0x13eab8400>
# gc: collectable <list 0x13e860940>
# gc: collectable <list 0x13f3b4d00>
# gc: collectable <list 0x10771a740>
# gc: collectable <method 0x13f3b2c00>
# gc: collectable <functools.partial 0x1075afa90>
# gc: collectable <tuple 0x107540520>
# gc: collectable <list 0x14ec44200>
# gc: collectable <Future 0x1075b6580>
# gc: collectable <Condition 0x1075b62e0>
# gc: collectable <builtin_function_or_method 0x13ee65a90>
# gc: collectable <dict 0x13f43f400>
# gc: collectable <builtin_function_or_method 0x107720900>
# gc: collectable <builtin_function_or_method 0x1077207c0>
# gc: collectable <builtin_function_or_method 0x107720a90>
# gc: collectable <builtin_function_or_method 0x107720ae0>
# gc: collectable <collections.deque 0x110094820>
# gc: collectable <dict 0x13f43fe00>
# gc: collectable <list 0x13ef59200>
# gc: collectable <list 0x13ea5c600>
# gc: collectable <method 0x14ecdd240>
# gc: collectable <functools.partial 0x14ec11040>
# gc: collectable <tuple 0x11d20ac70>
# gc: collectable <list 0x14ecd4e80>
# gc: collectable <dict 0x13f43f600>
# gc: collectable <list 0x13ee8b080>
# gc: collectable <list 0x13f3b49c0>
# gc: collectable <dict 0x13f3b2b40>
# gc: collectable <AppFuture 0x107705ac0>
# gc: collectable <Condition 0x1077052b0>
# gc: collectable <builtin_function_or_method 0x107472cc0>
# gc: collectable <dict 0x13f43f280>
# gc: collectable <builtin_function_or_method 0x14ebf9810>
# gc: collectable <builtin_function_or_method 0x107720950>
# gc: collectable <builtin_function_or_method 0x1077208b0>
# gc: collectable <builtin_function_or_method 0x107720770>
# gc: collectable <collections.deque 0x1100942e0>
# gc: collectable <dict 0x13f31b480>
# gc: collectable <list 0x14ecddd80>
# gc: collectable <list 0x14ecdd440>
# gc: collectable <list 0x11f0c4800>
# gc: collectable <list 0x13ec03f80>
# gc: collectable <method 0x14eac0700>
# gc: collectable <functools.partial 0x107720040>
# gc: collectable <tuple 0x13f58c520>
# gc: collectable <list 0x13f3b9f80>
# gc: collectable <Future 0x1077059a0>
# gc: collectable <Condition 0x107705d60>
# gc: collectable <builtin_function_or_method 0x107720a40>
# gc: collectable <dict 0x14eac0e40>
# gc: collectable <builtin_function_or_method 0x107720db0>
# gc: collectable <builtin_function_or_method 0x107720e00>
# gc: collectable <builtin_function_or_method 0x107720e50>
# gc: collectable <builtin_function_or_method 0x107720ea0>
# gc: collectable <collections.deque 0x107580e20>
# gc: collectable <dict 0x13e852d00>
# gc: collectable <list 0x13f3b9280>
# gc: collectable <list 0x13f3b9400>
# gc: collectable <list 0x13f3b9600>
# gc: collectable <method 0x14ec096c0>
# gc: collectable <functools.partial 0x14ec64ae0>
# gc: collectable <tuple 0x13efedca0>
# gc: collectable <list 0x14ecddec0>
# gc: collectable <dict 0x14ec61200>
# gc: collectable <AppFuture 0x107705970>
# gc: collectable <Condition 0x107705df0>
# gc: collectable <builtin_function_or_method 0x107720f40>
# gc: collectable <dict 0x14ec61080>
# gc: collectable <builtin_function_or_method 0x107720f90>
# gc: collectable <builtin_function_or_method 0x107720090>
# gc: collectable <builtin_function_or_method 0x1077200e0>
# gc: collectable <builtin_function_or_method 0x107720ef0>
# gc: collectable <collections.deque 0x110094400>
# gc: collectable <dict 0x14eab0240>
# gc: collectable <list 0x13f3b9c40>
# gc: collectable <list 0x13f3b98c0>
# gc: collectable <list 0x13f3b9e40>
# gc: collectable <list 0x14eac3040>
# gc: collectable <method 0x13f41ddc0>
# gc: collectable <functools.partial 0x107720400>
# gc: collectable <tuple 0x1075b69a0>
# gc: collectable <list 0x13f3b9140>
# gc: collectable <Future 0x107705070>
# gc: collectable <Condition 0x107705eb0>
# gc: collectable <builtin_function_or_method 0x107720180>
# gc: collectable <dict 0x13f3b4880>
# gc: collectable <builtin_function_or_method 0x107720310>
# gc: collectable <builtin_function_or_method 0x107720130>
# gc: collectable <builtin_function_or_method 0x107720450>
# gc: collectable <builtin_function_or_method 0x1077204a0>
# gc: collectable <collections.deque 0x110094c40>
# gc: collectable <dict 0x13f3b4340>
# gc: collectable <list 0x14ecb8540>
# gc: collectable <list 0x13f3b7800>
# gc: collectable <cell 0x107705820>
# gc: collectable <cell 0x1077058b0>
# gc: collectable <cell 0x10770bfa0>
# gc: collectable <cell 0x10770bc40>
# gc: collectable <cell 0x10770beb0>
# gc: collectable <tuple 0x14eb117c0>
# gc: collectable <function 0x14eadfa60>
# gc: collectable <method 0x13e84e100>
# gc: collectable <functools.partial 0x14ec9ab30>
# gc: collectable <tuple 0x13eead7f0>
# gc: collectable <dict 0x13e84e240>
# gc: collectable <cell 0x107705e80>
# gc: collectable <cell 0x107705ca0>
# gc: collectable <list 0x13f43f200>
# gc: collectable <list 0x13f3b9500>
# gc: collectable <dict 0x14eaba940>
# gc: collectable <AppFuture 0x107705220>
# gc: collectable <Condition 0x10770bd90>
# gc: collectable <builtin_function_or_method 0x1077201d0>
# gc: collectable <dict 0x14eabab80>
# gc: collectable <builtin_function_or_method 0x107720270>
# gc: collectable <builtin_function_or_method 0x107720220>
# gc: collectable <builtin_function_or_method 0x1077202c0>
# gc: collectable <builtin_function_or_method 0x10772ae50>
# gc: collectable <collections.deque 0x110094940>
# gc: collectable <dict 0x14eaba640>
# gc: collectable <list 0x13f3b7480>
# gc: collectable <list 0x13f3b7b00>
# gc: collectable <list 0x13f3b7540>
# gc: collectable <list 0x13f3b7780>
# gc: collectable <method 0x14eabab40>
# gc: collectable <functools.partial 0x10772ad10>
# gc: collectable <tuple 0x13efedc10>
# gc: collectable <PosixPath 0x110094ca0>
# gc: collectable <list 0x14eabaa00>
# gc: collectable <tuple 0x11005ef00>
# gc: collectable <function 0x1075b5ca0>
# gc: collectable <dict 0x14eabaf80>
# gc: collectable <cell 0x107599e80>
# gc: collectable <cell 0x107599550>
# gc: collectable <list 0x14eaafcc0>
# gc: collectable <list 0x13f3b7440>
# gc: collectable <list 0x13f3b75c0>
# gc: collectable <dict 0x14eabae40>
# gc: collectable <AppFuture 0x1075990a0>
# gc: collectable <Condition 0x107599eb0>
# gc: collectable <builtin_function_or_method 0x10772a1d0>
# gc: collectable <dict 0x14eaba340>
# gc: collectable <builtin_function_or_method 0x10772a8b0>
# gc: collectable <builtin_function_or_method 0x10772a130>
# gc: collectable <builtin_function_or_method 0x10772a090>
# gc: collectable <builtin_function_or_method 0x10772a040>
# gc: collectable <collections.deque 0x110094be0>
# gc: collectable <dict 0x14eaba480>
# gc: collectable <list 0x13f3b2fc0>
# gc: collectable <list 0x13f3b2200>
# gc: collectable <Future 0x1075990d0>
# gc: collectable <Condition 0x107599f40>
# gc: collectable <builtin_function_or_method 0x10772a680>
# gc: collectable <dict 0x14eab9100>
# gc: collectable <builtin_function_or_method 0x10774e220>
# gc: collectable <builtin_function_or_method 0x10774e1d0>
# gc: collectable <builtin_function_or_method 0x10774e4f0>
# gc: collectable <builtin_function_or_method 0x10774e2c0>
# gc: collectable <collections.deque 0x110094d00>
# gc: collectable <dict 0x14eab9580>
# gc: collectable <list 0x14eabaf40>
# gc: collectable <list 0x13f3b2bc0>
# gc: collectable <list 0x13f31bb40>
# gc: collectable <list 0x14ec27e80>
# gc: collectable <method 0x14eab9240>
# gc: collectable <functools.partial 0x10772a4a0>
# gc: collectable <tuple 0x107566b50>
# gc: collectable <method 0x14eab9340>
# gc: collectable <functools.partial 0x10772a4f0>
# gc: collectable <tuple 0x13efedbe0>
# gc: collectable <tuple 0x107594080>
# gc: collectable <function 0x1075b5f70>
# gc: collectable <dict 0x14eab9400>
# gc: collectable <cell 0x107705a90>
# gc: collectable <cell 0x1075994c0>
# gc: collectable <list 0x13f3b7080>
# gc: collectable <list 0x14eaba300>
# gc: collectable <dict 0x14eaba5c0>
# gc: collectable <AppFuture 0x107599cd0>
# gc: collectable <Condition 0x107599640>
# gc: collectable <builtin_function_or_method 0x14ec648b0>
# gc: collectable <dict 0x14eab91c0>
# gc: collectable <builtin_function_or_method 0x1074766d0>
# gc: collectable <builtin_function_or_method 0x10772a180>
# gc: collectable <builtin_function_or_method 0x10774e4a0>
# gc: collectable <builtin_function_or_method 0x10774e540>
# gc: collectable <collections.deque 0x110094d60>
# gc: collectable <dict 0x14eaba140>
# gc: collectable <list 0x13f3b9800>
# gc: collectable <list 0x13f3b9d40>
# gc: collectable <list 0x13f3b9880>
# gc: collectable <list 0x14eab94c0>
# gc: collectable <method 0x14eab9680>
# gc: collectable <functools.partial 0x10774e360>
# gc: collectable <tuple 0x13efedc70>
# gc: collectable <tuple 0x14ecb81c0>
# gc: collectable <function 0x1075b5c10>
# gc: collectable <tuple 0x14ec8d880>
# gc: collectable <function 0x1075b5af0>
# gc: collectable <method 0x14eaaf800>
# gc: collectable <functools.partial 0x10774e310>
# gc: collectable <tuple 0x13efedac0>
# gc: collectable <list 0x14ec27d80>
# gc: collectable <list 0x13f3b2080>
# gc: collectable <PosixPath 0x110094dc0>
# gc: collectable <dict 0x13f3b4100>
# gc: collectable <dict 0x14ec61cc0>
# gc: collectable <list 0x13f3b70c0>
# gc: collectable <list 0x14eabafc0>
# gc: collectable <PosixPath 0x110094100>
# gc: collectable <dict 0x14ec61100>
# gc: collectable <list 0x13f3b5e00>
# gc: collectable <list 0x14ec8bcc0>
# gc: collectable <PosixPath 0x1100941c0>
# gc: collectable <dict 0x14eab9a80>
# gc: collectable <list 0x14ec8bd80>
# gc: collectable <list 0x14ec8bac0>
# gc: collectable <PosixPath 0x107474a60>
# gc: collectable <dict 0x14eab92c0>
# gc: collectable <list 0x13f3bac00>
# gc: collectable <Future 0x10771ce80>
# gc: collectable <Condition 0x10771c970>
# gc: collectable <builtin_function_or_method 0x10774e680>
# gc: collectable <dict 0x14eaaf640>
# gc: collectable <builtin_function_or_method 0x10774ea40>
# gc: collectable <builtin_function_or_method 0x10774e9a0>
# gc: collectable <builtin_function_or_method 0x10774e9f0>
# gc: collectable <builtin_function_or_method 0x10774ed10>
# gc: collectable <collections.deque 0x110094e80>
# gc: collectable <dict 0x13f43f7c0>
# gc: collectable <list 0x14ec61280>
# gc: collectable <list 0x13f3b9440>
# gc: collectable <method 0x14eab9b00>
# gc: collectable <functools.partial 0x10774e900>
# gc: collectable <tuple 0x13e828eb0>
# gc: collectable <list 0x13f3ba180>
# gc: collectable <Future 0x10774c190>
# gc: collectable <Condition 0x10774c310>
# gc: collectable <builtin_function_or_method 0x10774e5e0>
# gc: collectable <dict 0x14eab9d40>
# gc: collectable <builtin_function_or_method 0x10774ed60>
# gc: collectable <builtin_function_or_method 0x10774ec20>
# gc: collectable <builtin_function_or_method 0x10774ebd0>
# gc: collectable <builtin_function_or_method 0x10774ec70>
# gc: collectable <collections.deque 0x110094e20>
# gc: collectable <dict 0x14eab96c0>
# gc: collectable <list 0x14ec61d00>
# gc: collectable <list 0x14ec8bf40>
# gc: collectable <method 0x14eab9e80>
# gc: collectable <functools.partial 0x10774e720>
# gc: collectable <tuple 0x13efedeb0>
# gc: collectable <list 0x14eab9f40>
# gc: collectable <dict 0x14eab9a00>
# gc: collectable <list 0x14ec8bb40>
# gc: collectable <list 0x14ecdd880>
# gc: collectable <list 0x14ec8bc00>
# gc: collectable <cell 0x107599040>
# gc: collectable <cell 0x1077051f0>
# gc: collectable <cell 0x10774c280>
# gc: collectable <cell 0x10774c250>
# gc: collectable <cell 0x10774c040>
# gc: collectable <tuple 0x1100904f0>
# gc: collectable <function 0x1075b5b80>
# gc: collectable <dict 0x13e84eb80>
# gc: collectable <list 0x14ec8bd40>
# gc: collectable <list 0x14ec8bfc0>
# gc: collectable <dict 0x14eab4300>
# gc: collectable <AppFuture 0x10774c550>
# gc: collectable <Condition 0x10774c400>
# gc: collectable <builtin_function_or_method 0x10774e770>
# gc: collectable <dict 0x14eab4580>
# gc: collectable <builtin_function_or_method 0x10774e6d0>
# gc: collectable <builtin_function_or_method 0x10774eb30>
# gc: collectable <builtin_function_or_method 0x10774ee50>
# gc: collectable <builtin_function_or_method 0x10774edb0>
# gc: collectable <collections.deque 0x110094f40>
# gc: collectable <dict 0x14eab4780>
# gc: collectable <list 0x14ecd4d40>
# gc: collectable <list 0x14ebe3d40>
# gc: collectable <list 0x14ec57640>
# gc: collectable <list 0x14eab40c0>
# gc: collectable <method 0x14eab4500>
# gc: collectable <functools.partial 0x10774eef0>
# gc: collectable <tuple 0x13efed4c0>
# gc: collectable <list 0x14ec59100>
# gc: collectable <Future 0x10774c5b0>
# gc: collectable <Condition 0x10774c5e0>
# gc: collectable <builtin_function_or_method 0x10774eea0>
# gc: collectable <dict 0x14eab4d40>
# gc: collectable <builtin_function_or_method 0x10774e0e0>
# gc: collectable <builtin_function_or_method 0x10774e130>
# gc: collectable <builtin_function_or_method 0x107758220>
# gc: collectable <builtin_function_or_method 0x1077581d0>
# gc: collectable <collections.deque 0x110094ee0>
# gc: collectable <dict 0x14eab4880>
# gc: collectable <list 0x14eccfd00>
# gc: collectable <list 0x14ec8b940>
# gc: collectable <method 0x14eab4ac0>
# gc: collectable <functools.partial 0x10774ef90>
# gc: collectable <tuple 0x1100831c0>
# gc: collectable <list 0x14eab4f80>
# gc: collectable <dict 0x14eab9f00>
# gc: collectable <dict 0x14eab9480>
# gc: collectable <list 0x14ecddc80>
# gc: collectable <list 0x14ecddfc0>
# gc: collectable <dict 0x14eab4d80>
# gc: collectable <AppFuture 0x10774c1f0>
# gc: collectable <Condition 0x10774ccd0>
# gc: collectable <builtin_function_or_method 0x10774e040>
# gc: collectable <dict 0x14eab4a00>
# gc: collectable <builtin_function_or_method 0x10774ef40>
# gc: collectable <builtin_function_or_method 0x10774e090>
# gc: collectable <builtin_function_or_method 0x107758130>
# gc: collectable <builtin_function_or_method 0x1077580e0>
# gc: collectable <collections.deque 0x107743040>
# gc: collectable <dict 0x14eab4840>
# gc: collectable <list 0x14ecddb40>
# gc: collectable <list 0x14ec61700>
# gc: collectable <list 0x14ecdad80>
# gc: collectable <list 0x14eab1e80>
# gc: collectable <method 0x14eab1f00>
# gc: collectable <functools.partial 0x107758090>
# gc: collectable <tuple 0x13efeddc0>
# gc: collectable <list 0x14ec27b00>
# gc: collectable <Future 0x10774c880>
# gc: collectable <Condition 0x10774c8b0>
# gc: collectable <builtin_function_or_method 0x107758040>
# gc: collectable <dict 0x14eab1900>
# gc: collectable <builtin_function_or_method 0x107758680>
# gc: collectable <builtin_function_or_method 0x107758450>
# gc: collectable <builtin_function_or_method 0x1077583b0>
# gc: collectable <builtin_function_or_method 0x107758590>
# gc: collectable <collections.deque 0x1077430a0>
# gc: collectable <dict 0x14eab1840>
# gc: collectable <list 0x11007fdc0>
# gc: collectable <list 0x14eab1a00>
# gc: collectable <method 0x14eab1e40>
# gc: collectable <functools.partial 0x107758360>
# gc: collectable <tuple 0x13efed520>
# gc: collectable <list 0x14eab1cc0>
# gc: collectable <dict 0x14eab4bc0>
# gc: collectable <dict 0x14eab4c80>
# gc: collectable <list 0x14ec57340>
# gc: collectable <list 0x14eab17c0>
# gc: collectable <dict 0x14eab1ec0>
# gc: collectable <AppFuture 0x10774c520>
# gc: collectable <Condition 0x10774c6d0>
# gc: collectable <builtin_function_or_method 0x107758310>
# gc: collectable <dict 0x14eab1ac0>
# gc: collectable <builtin_function_or_method 0x1077582c0>
# gc: collectable <builtin_function_or_method 0x107758c20>
# gc: collectable <builtin_function_or_method 0x107758630>
# gc: collectable <builtin_function_or_method 0x1077585e0>
# gc: collectable <collections.deque 0x107743100>
# gc: collectable <dict 0x14eab1e00>
# gc: collectable <list 0x14eab1080>
# gc: collectable <list 0x14eab10c0>
# gc: collectable <list 0x14eab1280>
# gc: collectable <list 0x14eab1200>
# gc: collectable <method 0x14eab1600>
# gc: collectable <functools.partial 0x1077584a0>
# gc: collectable <tuple 0x13efed910>
# gc: collectable <list 0x13f5c2240>
# gc: collectable <Future 0x10774c790>
# gc: collectable <Condition 0x10774ca90>
# gc: collectable <builtin_function_or_method 0x107758950>
# gc: collectable <dict 0x13f5c22c0>
# gc: collectable <builtin_function_or_method 0x1077588b0>
# gc: collectable <builtin_function_or_method 0x1077587c0>
# gc: collectable <builtin_function_or_method 0x1077586d0>
# gc: collectable <builtin_function_or_method 0x1077589f0>
# gc: collectable <collections.deque 0x107743160>
# gc: collectable <dict 0x13f5c2480>
# gc: collectable <list 0x13f5c2380>
# gc: collectable <list 0x13f5c2c00>
# gc: collectable <method 0x13f5c23c0>
# gc: collectable <functools.partial 0x107758720>
# gc: collectable <tuple 0x13efedd00>
# gc: collectable <list 0x13f5c2900>
# gc: collectable <dict 0x14eab1940>
# gc: collectable <dict 0x14eab1b00>
# gc: collectable <list 0x14ecda980>
# gc: collectable <list 0x13f5c2b80>
# gc: collectable <dict 0x13f5c2200>
# gc: collectable <AppFuture 0x10774cf10>
# gc: collectable <Condition 0x10774c9d0>
# gc: collectable <builtin_function_or_method 0x107758810>
# gc: collectable <dict 0x14eab1140>
# gc: collectable <builtin_function_or_method 0x107758860>
# gc: collectable <builtin_function_or_method 0x107758900>
# gc: collectable <builtin_function_or_method 0x107758bd0>
# gc: collectable <builtin_function_or_method 0x107758c70>
# gc: collectable <collections.deque 0x1077431c0>
# gc: collectable <dict 0x14eab1400>
# gc: collectable <list 0x13f5c27c0>
# gc: collectable <list 0x13f5c2700>
# gc: collectable <list 0x13f5c2f40>
# gc: collectable <list 0x13f5c02c0>
# gc: collectable <method 0x13f5c0740>
# gc: collectable <functools.partial 0x107758ae0>
# gc: collectable <tuple 0x13efedb50>
# gc: collectable <list 0x13f5c0f80>
# gc: collectable <Future 0x10774cbe0>
# gc: collectable <Condition 0x10774cc10>
# gc: collectable <builtin_function_or_method 0x107758b80>
# gc: collectable <dict 0x13f5c0fc0>
# gc: collectable <builtin_function_or_method 0x107758d10>
# gc: collectable <builtin_function_or_method 0x107758e00>
# gc: collectable <builtin_function_or_method 0x107758ea0>
# gc: collectable <builtin_function_or_method 0x107758db0>
# gc: collectable <collections.deque 0x107743220>
# gc: collectable <dict 0x13f5be2c0>
# gc: collectable <list 0x13f5c0e00>
# gc: collectable <list 0x13f5be040>
# gc: collectable <method 0x13f5c0840>
# gc: collectable <functools.partial 0x107758a90>
# gc: collectable <tuple 0x13efed2b0>
# gc: collectable <list 0x14ebfe880>
# gc: collectable <dict 0x13f5c2e80>
# gc: collectable <list 0x13f5c2c40>
# gc: collectable <list 0x13f3b9900>
# gc: collectable <dict 0x13f5c2300>
# gc: collectable <list 0x13f5c2780>
# gc: collectable <list 0x13f5bed00>
# gc: collectable <dict 0x13f5c07c0>
# gc: collectable <AppFuture 0x10774ce20>
# gc: collectable <Condition 0x10774ce50>
# gc: collectable <builtin_function_or_method 0x14ec64810>
# gc: collectable <dict 0x13f5c0300>
# gc: collectable <builtin_function_or_method 0x107758a40>
# gc: collectable <builtin_function_or_method 0x107758d60>
# gc: collectable <builtin_function_or_method 0x107758cc0>
# gc: collectable <builtin_function_or_method 0x107758f40>
# gc: collectable <collections.deque 0x107743280>
# gc: collectable <dict 0x13f5c0d00>
# gc: collectable <list 0x13f5bed80>
# gc: collectable <list 0x13f5bec40>
# gc: collectable <list 0x13f5bec80>
# gc: collectable <list 0x13f5be480>
# gc: collectable <method 0x13f5be900>
# gc: collectable <functools.partial 0x107758e50>
# gc: collectable <tuple 0x13efed970>
# gc: collectable <list 0x13f5bb100>
# gc: collectable <Future 0x107760520>
# gc: collectable <Condition 0x107760610>
# gc: collectable <builtin_function_or_method 0x107769130>
# gc: collectable <dict 0x13f5bb2c0>
# gc: collectable <builtin_function_or_method 0x1077691d0>
# gc: collectable <builtin_function_or_method 0x13e9e65e0>
# gc: collectable <builtin_function_or_method 0x110055e50>
# gc: collectable <builtin_function_or_method 0x110055b80>
# gc: collectable <collections.deque 0x1077432e0>
# gc: collectable <dict 0x13f5bb440>
# gc: collectable <list 0x13f5bb300>
# gc: collectable <list 0x13f5bbcc0>
# gc: collectable <method 0x13f5bb140>
# gc: collectable <functools.partial 0x107769090>
# gc: collectable <tuple 0x13eee6100>
# gc: collectable <dict 0x13f5bef40>
# gc: collectable <cell 0x10774cee0>
# gc: collectable <cell 0x10774cb50>
# gc: collectable <list 0x13f5be700>
# gc: collectable <list 0x13f5be980>
# gc: collectable <dict 0x13f5befc0>
# gc: collectable <AppFuture 0x107760160>
# gc: collectable <Condition 0x1077600d0>
# gc: collectable <builtin_function_or_method 0x107769040>
# gc: collectable <dict 0x13f5bbb40>
# gc: collectable <builtin_function_or_method 0x1077690e0>
# gc: collectable <builtin_function_or_method 0x107769220>
# gc: collectable <builtin_function_or_method 0x107769180>
# gc: collectable <builtin_function_or_method 0x110055f40>
# gc: collectable <collections.deque 0x107743340>
# gc: collectable <dict 0x13f5bb5c0>
# gc: collectable <list 0x13f5bbbc0>
# gc: collectable <list 0x13f5bb400>
# gc: collectable <list 0x13f5bb4c0>
# gc: collectable <list 0x13f5bb800>
# gc: collectable <method 0x13f5bbac0>
# gc: collectable <functools.partial 0x110055a90>
# gc: collectable <tuple 0x13efed490>
# gc: collectable <tuple 0x107590280>
# gc: collectable <function 0x110084dc0>
# gc: collectable <list 0x13f5bb500>
# gc: collectable <Future 0x107760250>
# gc: collectable <Condition 0x1077602b0>
# gc: collectable <builtin_function_or_method 0x14ec955e0>
# gc: collectable <dict 0x13f5bbe40>
# gc: collectable <builtin_function_or_method 0x110055950>
# gc: collectable <builtin_function_or_method 0x1100557c0>
# gc: collectable <builtin_function_or_method 0x110055cc0>
# gc: collectable <builtin_function_or_method 0x110055ae0>
# gc: collectable <collections.deque 0x1077433a0>
# gc: collectable <dict 0x14ec59800>
# gc: collectable <list 0x13f5b4a00>
# gc: collectable <list 0x13f5bb880>
# gc: collectable <method 0x13f5bbf40>
# gc: collectable <functools.partial 0x10774ea90>
# gc: collectable <tuple 0x13ef3faf0>
# gc: collectable <dict 0x13f5b4ec0>
# gc: collectable <list 0x13f5b4080>
# gc: collectable <list 0x14eab18c0>
# gc: collectable <dict 0x13f5b98c0>
# gc: collectable <list 0x13f5b4640>
# gc: collectable <list 0x13f5b4440>
# gc: collectable <dict 0x13f5b4e00>
# gc: collectable <AppFuture 0x107760490>
# gc: collectable <Condition 0x1077606d0>
# gc: collectable <builtin_function_or_method 0x110062d10>
# gc: collectable <dict 0x13f5b4e40>
# gc: collectable <builtin_function_or_method 0x110090720>
# gc: collectable <builtin_function_or_method 0x110090770>
# gc: collectable <builtin_function_or_method 0x110090450>
# gc: collectable <builtin_function_or_method 0x1100907c0>
# gc: collectable <collections.deque 0x107743400>
# gc: collectable <dict 0x13f5bbf80>
# gc: collectable <list 0x13f5b46c0>
# gc: collectable <list 0x13f5b7b40>
# gc: collectable <list 0x13f5b77c0>
# gc: collectable <list 0x13f5b7b80>
# gc: collectable <method 0x13f5b7c00>
# gc: collectable <functools.partial 0x1100908b0>
# gc: collectable <tuple 0x13f43c310>
# gc: collectable <list 0x13f5b7b00>
# gc: collectable <Future 0x1077605e0>
# gc: collectable <Condition 0x107760190>
# gc: collectable <builtin_function_or_method 0x110090950>
# gc: collectable <dict 0x13f5b9f80>
# gc: collectable <builtin_function_or_method 0x1100909f0>
# gc: collectable <builtin_function_or_method 0x110090ae0>
# gc: collectable <builtin_function_or_method 0x110090b80>
# gc: collectable <builtin_function_or_method 0x110090b30>
# gc: collectable <collections.deque 0x107743460>
# gc: collectable <dict 0x13f5b4840>
# gc: collectable <list 0x13f5b7a40>
# gc: collectable <list 0x13f5b7e00>
# gc: collectable <method 0x13f5b7480>
# gc: collectable <functools.partial 0x10772a9f0>
# gc: collectable <tuple 0x13efed580>
# gc: collectable <dict 0x13f5b48c0>
# gc: collectable <cell 0x107760700>
# gc: collectable <cell 0x107760100>
# gc: collectable <list 0x13f5b49c0>
# gc: collectable <list 0x13f5b4340>
# gc: collectable <dict 0x14eaa4480>
# gc: collectable <AppFuture 0x1077607f0>
# gc: collectable <Condition 0x107760670>
# gc: collectable <builtin_function_or_method 0x110090860>
# gc: collectable <dict 0x14eaa4040>
# gc: collectable <builtin_function_or_method 0x1100909a0>
# gc: collectable <builtin_function_or_method 0x110090900>
# gc: collectable <builtin_function_or_method 0x110090a40>
# gc: collectable <builtin_function_or_method 0x110090a90>
# gc: collectable <collections.deque 0x1077434c0>
# gc: collectable <dict 0x14eaa4080>
# gc: collectable <list 0x14eaa4200>
# gc: collectable <list 0x13f5b7380>
# gc: collectable <list 0x14eaa4e80>
# gc: collectable <list 0x14eaa4f80>
# gc: collectable <method 0x14eaa4bc0>
# gc: collectable <functools.partial 0x110090d10>
# gc: collectable <tuple 0x13efedd60>
# gc: collectable <tuple 0x14ec6aa80>
# gc: collectable <function 0x110084e50>
# gc: collectable <list 0x13f5b79c0>
# gc: collectable <Future 0x107760850>
# gc: collectable <Condition 0x1077608e0>
# gc: collectable <builtin_function_or_method 0x110090c70>
# gc: collectable <dict 0x13f5c0a80>
# gc: collectable <builtin_function_or_method 0x110090ea0>
# gc: collectable <builtin_function_or_method 0x110090ef0>
# gc: collectable <builtin_function_or_method 0x110090f40>
# gc: collectable <builtin_function_or_method 0x110090f90>
# gc: collectable <collections.deque 0x107743520>
# gc: collectable <dict 0x13e818780>
# gc: collectable <list 0x14eaa4100>
# gc: collectable <list 0x14eaa4440>
# gc: collectable <method 0x13f5b4780>
# gc: collectable <functools.partial 0x110090db0>
# gc: collectable <tuple 0x13efed700>
# gc: collectable <dict 0x13f5b4880>
# gc: collectable <list 0x13f5b4140>
# gc: collectable <list 0x14eabbe80>
# gc: collectable <dict 0x13f5b7980>
# gc: collectable <list 0x14eabb680>
# gc: collectable <list 0x14eabba80>
# gc: collectable <dict 0x14eaa4600>
# gc: collectable <AppFuture 0x1077604c0>
# gc: collectable <Condition 0x107760910>
# gc: collectable <builtin_function_or_method 0x110055db0>
# gc: collectable <dict 0x13f5b71c0>
# gc: collectable <builtin_function_or_method 0x110055b30>
# gc: collectable <builtin_function_or_method 0x110055860>
# gc: collectable <builtin_function_or_method 0x110055c20>
# gc: collectable <builtin_function_or_method 0x110055f90>
# gc: collectable <collections.deque 0x107743580>
# gc: collectable <dict 0x13f5b7f40>
# gc: collectable <list 0x13f5b13c0>
# gc: collectable <list 0x13f5b1140>
# gc: collectable <list 0x13f5b1480>
# gc: collectable <list 0x13f5b1d00>
# gc: collectable <method 0x13f5b1a80>
# gc: collectable <functools.partial 0x110055d60>
# gc: collectable <tuple 0x13efed820>
# gc: collectable <list 0x13f5b1b40>
# gc: collectable <Future 0x1077608b0>
# gc: collectable <Condition 0x107760be0>
# gc: collectable <builtin_function_or_method 0x110090e50>
# gc: collectable <dict 0x14eabb2c0>
# gc: collectable <builtin_function_or_method 0x1077490e0>
# gc: collectable <builtin_function_or_method 0x107749130>
# gc: collectable <builtin_function_or_method 0x107749180>
# gc: collectable <builtin_function_or_method 0x1077491d0>
# gc: collectable <collections.deque 0x1077435e0>
# gc: collectable <dict 0x14eabb900>
# gc: collectable <list 0x13f5b1600>
# gc: collectable <list 0x13f5b0380>
# gc: collectable <method 0x13f5b1640>
# gc: collectable <functools.partial 0x110090e00>
# gc: collectable <tuple 0x1100831f0>
# gc: collectable <dict 0x14eaa43c0>
# gc: collectable <cell 0x107760c10>
# gc: collectable <cell 0x107760940>
# gc: collectable <list 0x14eabb840>
# gc: collectable <list 0x13f5b1d40>
# gc: collectable <dict 0x14eabb740>
# gc: collectable <AppFuture 0x107760d00>
# gc: collectable <Condition 0x107760c70>
# gc: collectable <builtin_function_or_method 0x110090d60>
# gc: collectable <dict 0x13f5b08c0>
# gc: collectable <builtin_function_or_method 0x110090cc0>
# gc: collectable <builtin_function_or_method 0x107749040>
# gc: collectable <builtin_function_or_method 0x107749090>
# gc: collectable <builtin_function_or_method 0x107749270>
# gc: collectable <collections.deque 0x107743640>
# gc: collectable <dict 0x13f5b0980>
# gc: collectable <list 0x13f5b0400>
# gc: collectable <list 0x13f5b09c0>
# gc: collectable <list 0x13f5ad440>
# gc: collectable <list 0x13f5b0880>
# gc: collectable <method 0x13f5adbc0>
# gc: collectable <functools.partial 0x107749310>
# gc: collectable <tuple 0x13efed3d0>
# gc: collectable <tuple 0x14ecb8440>
# gc: collectable <function 0x14ecd5430>
# gc: collectable <list 0x13f5b00c0>
# gc: collectable <Future 0x1075a4b80>
# gc: collectable <Condition 0x1075a4dc0>
# gc: collectable <builtin_function_or_method 0x14ecb6360>
# gc: collectable <dict 0x14eaa4680>
# gc: collectable <builtin_function_or_method 0x1077494f0>
# gc: collectable <builtin_function_or_method 0x107749540>
# gc: collectable <builtin_function_or_method 0x107749590>
# gc: collectable <builtin_function_or_method 0x1077495e0>
# gc: collectable <collections.deque 0x1077436a0>
# gc: collectable <dict 0x14eabb540>
# gc: collectable <list 0x13f5b0d00>
# gc: collectable <list 0x13f5b0bc0>
# gc: collectable <method 0x13f5adec0>
# gc: collectable <functools.partial 0x107749400>
# gc: collectable <tuple 0x13eff6310>
# gc: collectable <dict 0x14eac6b40>
# gc: collectable <list 0x14eabb180>
# gc: collectable <list 0x14eac6180>
# gc: collectable <dict 0x13f5b0240>
# gc: collectable <list 0x14eac6300>
# gc: collectable <list 0x14eac6100>
# gc: collectable <dict 0x13f5adb80>
# gc: collectable <AppFuture 0x1075a4d30>
# gc: collectable <Condition 0x1075a4fa0>
# gc: collectable <builtin_function_or_method 0x107749360>
# gc: collectable <dict 0x14eac6cc0>
# gc: collectable <builtin_function_or_method 0x107749450>
# gc: collectable <builtin_function_or_method 0x1077494a0>
# gc: collectable <builtin_function_or_method 0x107749680>
# gc: collectable <builtin_function_or_method 0x1077496d0>
# gc: collectable <collections.deque 0x107743700>
# gc: collectable <dict 0x13f5ad580>
# gc: collectable <list 0x14eac6c40>
# gc: collectable <list 0x14eac6040>
# gc: collectable <list 0x14eabed80>
# gc: collectable <list 0x14eabe900>
# gc: collectable <method 0x14eabebc0>
# gc: collectable <functools.partial 0x107749770>
# gc: collectable <tuple 0x13f58c6a0>
# gc: collectable <list 0x14eabedc0>
# gc: collectable <Future 0x1075a4df0>
# gc: collectable <Condition 0x1075a4760>
# gc: collectable <builtin_function_or_method 0x107749860>
# gc: collectable <dict 0x14eac6d00>
# gc: collectable <builtin_function_or_method 0x1077499a0>
# gc: collectable <builtin_function_or_method 0x1077499f0>
# gc: collectable <builtin_function_or_method 0x107749a40>
# gc: collectable <builtin_function_or_method 0x107749a90>
# gc: collectable <collections.deque 0x107743760>
# gc: collectable <dict 0x14eac6c80>
# gc: collectable <list 0x14eabe040>
# gc: collectable <list 0x14eabe280>
# gc: collectable <method 0x14eabe2c0>
# gc: collectable <functools.partial 0x1100559f0>
# gc: collectable <tuple 0x13f58c5e0>
# gc: collectable <dict 0x13f5a7a00>
# gc: collectable <cell 0x107760ca0>
# gc: collectable <cell 0x13eead220>
# gc: collectable <list 0x14eac6ec0>
# gc: collectable <list 0x14eac62c0>
# gc: collectable <dict 0x13f5a49c0>
# gc: collectable <AppFuture 0x1075a47f0>
# gc: collectable <Condition 0x1075a4e80>
# gc: collectable <builtin_function_or_method 0x107749810>
# gc: collectable <dict 0x13f5a5400>
# gc: collectable <builtin_function_or_method 0x1077498b0>
# gc: collectable <builtin_function_or_method 0x1077497c0>
# gc: collectable <builtin_function_or_method 0x107749900>
# gc: collectable <builtin_function_or_method 0x107749950>
# gc: collectable <collections.deque 0x1077437c0>
# gc: collectable <dict 0x13f5a5e40>
# gc: collectable <list 0x13f5a50c0>
# gc: collectable <list 0x14eabe880>
# gc: collectable <list 0x13f5a5f80>
# gc: collectable <list 0x13f5a5280>
# gc: collectable <method 0x14ec5fd40>
# gc: collectable <functools.partial 0x107749c20>
# gc: collectable <tuple 0x13f43c880>
# gc: collectable <tuple 0x11007d1c0>
# gc: collectable <function 0x110033280>
# gc: collectable <list 0x14eabeec0>
# gc: collectable <Future 0x1075b2be0>
# gc: collectable <Condition 0x1075b2c40>
# gc: collectable <builtin_function_or_method 0x107749bd0>
# gc: collectable <dict 0x13f5a7640>
# gc: collectable <builtin_function_or_method 0x107749db0>
# gc: collectable <builtin_function_or_method 0x107749e00>
# gc: collectable <builtin_function_or_method 0x107749e50>
# gc: collectable <builtin_function_or_method 0x107749ea0>
# gc: collectable <collections.deque 0x107743820>
# gc: collectable <dict 0x13f5a7c00>
# gc: collectable <list 0x13f5a5d80>
# gc: collectable <list 0x13f5a5800>
# gc: collectable <method 0x14eac6580>
# gc: collectable <functools.partial 0x107749cc0>
# gc: collectable <tuple 0x13f43c3d0>
# gc: collectable <dict 0x14eac6900>
# gc: collectable <dict 0x14eabec80>
# gc: collectable <list 0x14ec5f040>
# gc: collectable <list 0x14ea11780>
# gc: collectable <dict 0x14ec5ffc0>
# gc: collectable <AppFuture 0x1075a4d90>
# gc: collectable <Condition 0x1075b2340>
# gc: collectable <builtin_function_or_method 0x107749b80>
# gc: collectable <dict 0x13f5a4c80>
# gc: collectable <builtin_function_or_method 0x107749d10>
# gc: collectable <builtin_function_or_method 0x107749d60>
# gc: collectable <builtin_function_or_method 0x107749f40>
# gc: collectable <builtin_function_or_method 0x107749f90>
# gc: collectable <collections.deque 0x107743880>
# gc: collectable <dict 0x13f5a4380>
# gc: collectable <list 0x14ea11bc0>
# gc: collectable <list 0x14ec5f6c0>
# gc: collectable <list 0x14ec5f440>
# gc: collectable <list 0x14ec5fbc0>
# gc: collectable <method 0x14ec5f140>
# gc: collectable <functools.partial 0x107752090>
# gc: collectable <tuple 0x13efedd30>
# gc: collectable <list 0x14ec5f2c0>
# gc: collectable <Future 0x1075b29d0>
# gc: collectable <Condition 0x1075b2c10>
# gc: collectable <builtin_function_or_method 0x1077520e0>
# gc: collectable <dict 0x14ec5f840>
# gc: collectable <builtin_function_or_method 0x107752270>
# gc: collectable <builtin_function_or_method 0x1077522c0>
# gc: collectable <builtin_function_or_method 0x107752310>
# gc: collectable <builtin_function_or_method 0x107752360>
# gc: collectable <collections.deque 0x1077438e0>
# gc: collectable <dict 0x14ec5f5c0>
# gc: collectable <list 0x14ec5bfc0>
# gc: collectable <list 0x14ec5bbc0>
# gc: collectable <method 0x14ec5bc40>
# gc: collectable <functools.partial 0x1077493b0>
# gc: collectable <tuple 0x13f43c0a0>
# gc: collectable <pyarrow._parquet.FileMetaData 0x107752180>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x14eac6640>
# gc: collectable <pyarrow._parquet.FileMetaData 0x107752f40>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x10772f540>
# gc: collectable <PosixPath 0x1077121c0>
# gc: collectable <list 0x10771d400>
# gc: collectable <dict 0x14ec5f700>
# gc: collectable <list 0x10771d700>
# gc: collectable <PosixPath 0x107712160>
# gc: collectable <list 0x10771dc00>
# gc: collectable <list 0x10771d740>
# gc: collectable <dict 0x13f5be300>
# gc: collectable <dict 0x13f5a4300>
# gc: collectable <list 0x10771da80>
# gc: collectable <list 0x10771d780>
# gc: collectable <dict 0x13f5a4340>
# gc: collectable <AppFuture 0x1075b28b0>
# gc: collectable <Condition 0x1075b2a60>
# gc: collectable <builtin_function_or_method 0x1077521d0>
# gc: collectable <dict 0x107597980>
# gc: collectable <builtin_function_or_method 0x107752400>
# gc: collectable <builtin_function_or_method 0x107752450>
# gc: collectable <builtin_function_or_method 0x1077524a0>
# gc: collectable <builtin_function_or_method 0x1077524f0>
# gc: collectable <collections.deque 0x107743940>
# gc: collectable <dict 0x14ec5b6c0>
# gc: collectable <list 0x10771d840>
# gc: collectable <list 0x10771d680>
# gc: collectable <list 0x10771dbc0>
# gc: collectable <list 0x1075b8e00>
# gc: collectable <method 0x1075b8080>
# gc: collectable <functools.partial 0x107752590>
# gc: collectable <tuple 0x13f43c340>
# gc: collectable <list 0x10771dd00>
# gc: collectable <Future 0x1075b2160>
# gc: collectable <Condition 0x1075b2190>
# gc: collectable <builtin_function_or_method 0x1077525e0>
# gc: collectable <dict 0x107575540>
# gc: collectable <builtin_function_or_method 0x107752770>
# gc: collectable <builtin_function_or_method 0x1077527c0>
# gc: collectable <builtin_function_or_method 0x107752810>
# gc: collectable <builtin_function_or_method 0x107752860>
# gc: collectable <collections.deque 0x1077439a0>
# gc: collectable <dict 0x107589380>
# gc: collectable <list 0x10771d280>
# gc: collectable <list 0x10771d5c0>
# gc: collectable <method 0x1075b82c0>
# gc: collectable <functools.partial 0x107752630>
# gc: collectable <tuple 0x13f43c1f0>
# gc: collectable <pyarrow._parquet.FileMetaData 0x107752680>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x107578cc0>
# gc: collectable <pyarrow._parquet.FileMetaData 0x107752f90>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x1075a18c0>
# gc: collectable <PosixPath 0x10771f3a0>
# gc: collectable <list 0x14ec8d200>
# gc: collectable <dict 0x1075b8ac0>
# gc: collectable <list 0x14ec8d480>
# gc: collectable <PosixPath 0x10771f340>
# gc: collectable <list 0x14ec8d3c0>
# gc: collectable <list 0x10758f140>
# gc: collectable <dict 0x14ec5bb40>
# gc: collectable <list 0x14ec8d180>
# gc: collectable <list 0x14ecd2380>
# gc: collectable <dict 0x1075b8f40>
# gc: collectable <AppFuture 0x1075b2280>
# gc: collectable <Condition 0x1075b2700>
# gc: collectable <builtin_function_or_method 0x1077526d0>
# gc: collectable <dict 0x107708b40>
# gc: collectable <builtin_function_or_method 0x107752900>
# gc: collectable <builtin_function_or_method 0x107752950>
# gc: collectable <builtin_function_or_method 0x1077529a0>
# gc: collectable <builtin_function_or_method 0x1077529f0>
# gc: collectable <collections.deque 0x107743a00>
# gc: collectable <dict 0x14ec5b3c0>
# gc: collectable <list 0x14ecd20c0>
# gc: collectable <list 0x107523080>
# gc: collectable <list 0x10770f900>
# gc: collectable <list 0x10759a940>
# gc: collectable <method 0x10759a2c0>
# gc: collectable <functools.partial 0x107752a90>
# gc: collectable <tuple 0x13eead730>
# gc: collectable <list 0x10770ff80>
# gc: collectable <Future 0x13eff6d90>
# gc: collectable <Condition 0x13eff61f0>
# gc: collectable <builtin_function_or_method 0x107752ae0>
# gc: collectable <dict 0x107708440>
# gc: collectable <builtin_function_or_method 0x107752c70>
# gc: collectable <builtin_function_or_method 0x107752cc0>
# gc: collectable <builtin_function_or_method 0x107752d10>
# gc: collectable <builtin_function_or_method 0x107752d60>
# gc: collectable <collections.deque 0x107743a60>
# gc: collectable <dict 0x107708640>
# gc: collectable <list 0x10770f640>
# gc: collectable <list 0x10770f840>
# gc: collectable <method 0x10759ad80>
# gc: collectable <functools.partial 0x107752b30>
# gc: collectable <tuple 0x1075b28e0>
# gc: collectable <pyarrow._parquet.FileMetaData 0x107752b80>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x10758f240>
# gc: collectable <pyarrow._parquet.FileMetaData 0x107752130>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x106846c80>
# gc: collectable <PosixPath 0x10774fb20>
# gc: collectable <list 0x107716680>
# gc: collectable <dict 0x107575140>
# gc: collectable <list 0x107716740>
# gc: collectable <PosixPath 0x10774fac0>
# gc: collectable <list 0x107716b40>
# gc: collectable <list 0x107716700>
# gc: collectable <dict 0x1077088c0>
# gc: collectable <list 0x107716140>
# gc: collectable <list 0x107716ac0>
# gc: collectable <dict 0x107708980>
# gc: collectable <AppFuture 0x13eff6e20>
# gc: collectable <Condition 0x13e529430>
# gc: collectable <builtin_function_or_method 0x107752220>
# gc: collectable <dict 0x14ec1ec40>
# gc: collectable <builtin_function_or_method 0x107752e00>
# gc: collectable <builtin_function_or_method 0x107752e50>
# gc: collectable <builtin_function_or_method 0x107752ea0>
# gc: collectable <builtin_function_or_method 0x107752ef0>
# gc: collectable <collections.deque 0x107743ac0>
# gc: collectable <dict 0x10759a480>
# gc: collectable <list 0x107716a80>
# gc: collectable <list 0x1077165c0>
# gc: collectable <list 0x107716880>
# gc: collectable <list 0x1075a1ec0>
# gc: collectable <method 0x1075a1e00>
# gc: collectable <functools.partial 0x107749c70>
# gc: collectable <tuple 0x1075b2100>
# gc: collectable <list 0x1077168c0>
# gc: collectable <Future 0x13e529a90>
# gc: collectable <Condition 0x13e529df0>
# gc: collectable <builtin_function_or_method 0x107742040>
# gc: collectable <dict 0x14ec92ac0>
# gc: collectable <builtin_function_or_method 0x1077421d0>
# gc: collectable <builtin_function_or_method 0x107742220>
# gc: collectable <builtin_function_or_method 0x107742270>
# gc: collectable <builtin_function_or_method 0x1077422c0>
# gc: collectable <collections.deque 0x107743b20>
# gc: collectable <dict 0x14ec92f00>
# gc: collectable <list 0x107716c00>
# gc: collectable <list 0x1077167c0>
# gc: collectable <method 0x1075a1080>
# gc: collectable <functools.partial 0x107752720>
# gc: collectable <tuple 0x13eff6d30>
# gc: collectable <pyarrow._parquet.FileMetaData 0x1077420e0>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x107755b80>
# gc: collectable <pyarrow._parquet.FileMetaData 0x107742f40>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x107716e80>
# gc: collectable <PosixPath 0x10775bfa0>
# gc: collectable <list 0x10773d1c0>
# gc: collectable <dict 0x107708140>
# gc: collectable <list 0x10773d300>
# gc: collectable <PosixPath 0x10775bf40>
# gc: collectable <list 0x10773d3c0>
# gc: collectable <list 0x10773d7c0>
# gc: collectable <dict 0x14ec1ea40>
# gc: collectable <list 0x10773d580>
# gc: collectable <list 0x10773d740>
# gc: collectable <dict 0x1075a1a00>
# gc: collectable <AppFuture 0x13e529700>
# gc: collectable <Condition 0x13e5297f0>
# gc: collectable <builtin_function_or_method 0x10774ecc0>
# gc: collectable <dict 0x1075a1580>
# gc: collectable <builtin_function_or_method 0x107742130>
# gc: collectable <builtin_function_or_method 0x107742360>
# gc: collectable <builtin_function_or_method 0x1077423b0>
# gc: collectable <builtin_function_or_method 0x107742400>
# gc: collectable <collections.deque 0x107743b80>
# gc: collectable <dict 0x10759a040>
# gc: collectable <list 0x10773d700>
# gc: collectable <list 0x10773d540>
# gc: collectable <list 0x10773d900>
# gc: collectable <list 0x1077083c0>
# gc: collectable <method 0x107708780>
# gc: collectable <functools.partial 0x1077424a0>
# gc: collectable <tuple 0x13e529910>
# gc: collectable <list 0x10773ddc0>
# gc: collectable <Future 0x13e529af0>
# gc: collectable <Condition 0x13e529b20>
# gc: collectable <builtin_function_or_method 0x1077424f0>
# gc: collectable <dict 0x10775c900>
# gc: collectable <builtin_function_or_method 0x107742680>
# gc: collectable <builtin_function_or_method 0x1077426d0>
# gc: collectable <builtin_function_or_method 0x107742720>
# gc: collectable <builtin_function_or_method 0x107742770>
# gc: collectable <collections.deque 0x107743be0>
# gc: collectable <dict 0x10775c440>
# gc: collectable <list 0x10773d6c0>
# gc: collectable <list 0x10773d880>
# gc: collectable <method 0x1077080c0>
# gc: collectable <functools.partial 0x107742540>
# gc: collectable <tuple 0x13e529850>
# gc: collectable <list 0x107708b00>
# gc: collectable <list 0x10773d780>
# gc: collectable <list 0x107708580>
# gc: collectable <dict 0x13f43ff40>
# gc: collectable <list 0x10773d8c0>
# gc: collectable <list 0x10773d800>
# gc: collectable <dict 0x12a386740>
# gc: collectable <AppFuture 0x13e529cd0>
# gc: collectable <Condition 0x13e5291f0>
# gc: collectable <builtin_function_or_method 0x107742590>
# gc: collectable <dict 0x1077372c0>
# gc: collectable <builtin_function_or_method 0x1077428b0>
# gc: collectable <builtin_function_or_method 0x107742810>
# gc: collectable <builtin_function_or_method 0x1077425e0>
# gc: collectable <builtin_function_or_method 0x107742860>
# gc: collectable <collections.deque 0x107743c40>
# gc: collectable <dict 0x107708dc0>
# gc: collectable <list 0x10773d980>
# gc: collectable <list 0x10773d380>
# gc: collectable <list 0x10773dd80>
# gc: collectable <list 0x107737480>
# gc: collectable <method 0x107737280>
# gc: collectable <functools.partial 0x107742950>
# gc: collectable <tuple 0x13e5296d0>
# gc: collectable <list 0x10773dc80>
# gc: collectable <Future 0x14eb0f820>
# gc: collectable <Condition 0x14eb0f760>
# gc: collectable <builtin_function_or_method 0x1077429a0>
# gc: collectable <dict 0x107737940>
# gc: collectable <builtin_function_or_method 0x107742b30>
# gc: collectable <builtin_function_or_method 0x107742b80>
# gc: collectable <builtin_function_or_method 0x107742bd0>
# gc: collectable <builtin_function_or_method 0x107742c20>
# gc: collectable <collections.deque 0x107743ca0>
# gc: collectable <dict 0x1077379c0>
# gc: collectable <list 0x10773dd40>
# gc: collectable <list 0x10773d5c0>
# gc: collectable <method 0x107737680>
# gc: collectable <functools.partial 0x1077429f0>
# gc: collectable <tuple 0x13e5293a0>
# gc: collectable <dict 0x10772b8c0>
# gc: collectable <list 0x1074b9180>
# gc: collectable <list 0x10773da00>
# gc: collectable <dict 0x10772bfc0>
# gc: collectable <AppFuture 0x14eb0f7c0>
# gc: collectable <Condition 0x14eb0f8e0>
# gc: collectable <builtin_function_or_method 0x107742180>
# gc: collectable <dict 0x10772ba00>
# gc: collectable <builtin_function_or_method 0x107742ae0>
# gc: collectable <builtin_function_or_method 0x107742cc0>
# gc: collectable <builtin_function_or_method 0x107742d10>
# gc: collectable <builtin_function_or_method 0x107742d60>
# gc: collectable <collections.deque 0x10775bee0>
# gc: collectable <dict 0x10772b200>
# gc: collectable <list 0x107708700>
# gc: collectable <list 0x107737100>
# gc: collectable <list 0x1075c0540>
# gc: collectable <list 0x10772f440>
# gc: collectable <method 0x107559980>
# gc: collectable <functools.partial 0x107742e00>
# gc: collectable <tuple 0x13e529070>
# gc: collectable <list 0x1075c0880>
# gc: collectable <Future 0x14eb0f790>
# gc: collectable <Condition 0x14eb0f700>
# gc: collectable <builtin_function_or_method 0x107742e50>
# gc: collectable <dict 0x10772b340>
# gc: collectable <builtin_function_or_method 0x107742a90>
# gc: collectable <builtin_function_or_method 0x107756040>
# gc: collectable <builtin_function_or_method 0x107756090>
# gc: collectable <builtin_function_or_method 0x1077560e0>
# gc: collectable <collections.deque 0x10775be80>
# gc: collectable <dict 0x10772b100>
# gc: collectable <list 0x1075c0700>
# gc: collectable <list 0x1075c0900>
# gc: collectable <method 0x107559740>
# gc: collectable <functools.partial 0x107742ea0>
# gc: collectable <tuple 0x14eb0f730>
# gc: collectable <pyarrow._parquet.FileMetaData 0x107742090>
# gc: collectable <pyarrow._parquet.ParquetSchema 0x1074b9f40>
# gc: collectable <list 0x11009a6c0>
# gc: collectable <list 0x11009a700>
# gc: collectable <dict 0x10772b980>
# gc: collectable <AppFuture 0x14eb0f670>
# gc: collectable <Condition 0x14eb0f5e0>
# gc: collectable <builtin_function_or_method 0x107756ef0>
# gc: collectable <dict 0x10772b640>
# gc: collectable <builtin_function_or_method 0x107756f90>
# gc: collectable <builtin_function_or_method 0x107756f40>
# gc: collectable <builtin_function_or_method 0x107756ea0>
# gc: collectable <builtin_function_or_method 0x107756e50>
# gc: collectable <collections.deque 0x1077129a0>
# gc: collectable <dict 0x10772b400>
# gc: collectable <list 0x11009a740>
# gc: collectable <list 0x11009a780>
# gc: collectable <list 0x11009a800>
# gc: collectable <list 0x10773da40>
# gc: collectable <method 0x1075c0d00>
# gc: collectable <functools.partial 0x107756db0>
# gc: collectable <tuple 0x14eb0fca0>
# gc: collectable <list 0x11009a840>
# gc: collectable <Future 0x14eb0f580>
# gc: collectable <Condition 0x14eb0fb20>
# gc: collectable <builtin_function_or_method 0x107756d60>
# gc: collectable <dict 0x10772b380>
# gc: collectable <builtin_function_or_method 0x107756bd0>
# gc: collectable <builtin_function_or_method 0x107756b80>
# gc: collectable <builtin_function_or_method 0x107756b30>
# gc: collectable <builtin_function_or_method 0x107756ae0>
# gc: collectable <collections.deque 0x107712940>
# gc: collectable <dict 0x10772b700>
# gc: collectable <list 0x11009a880>
# gc: collectable <list 0x11009a8c0>
# gc: collectable <method 0x1075c09c0>
# gc: collectable <functools.partial 0x107756d10>
# gc: collectable <tuple 0x14eb0f5b0>
# gc: collectable <method 0x1075599c0>
# gc: collectable <functools.partial 0x107756cc0>
# gc: collectable <tuple 0x13eff6ca0>
# gc: collectable <cell 0x14ea58d30>
# gc: collectable <tuple 0x14ea1d3d0>
# gc: collectable <function 0x110033e50>
#            id                                        type  refcount  \
# 0  5613734528                              <class 'list'>         9
# 1  5357606720                              <class 'list'>         4
# 2  5613836800                              <class 'dict'>         7
# 3  5351143936  <class 'parsl.dataflow.futures.AppFuture'>         4
# 4  5351144752               <class 'threading.Condition'>         4
#
#                                                 repr  size
# 0                                                 []    56
# 1                                                 []    56
# 2  {'depends': [], 'executor': '_parsl_internal',...  1176
# 3  <AppFuture at 0x13ef3fa00 state=finished retur...    48
# 4  <Condition(<unlocked _thread.RLock object owne...    48

# %%
df.sort_values(by=["size", "refcount"], ascending=False).drop_duplicates(
    subset="id"
).head(30)
# Out:
#               id            type  refcount  \
# 2     5613836800  <class 'dict'>         7
# 40    5616125760  <class 'dict'>         7
# 122   5616141376  <class 'dict'>         7
# 172   5616165248  <class 'dict'>         7
# 473   5616200512  <class 'dict'>         7
# 572   5616568064  <class 'dict'>         7
# 653   5617087680  <class 'dict'>         7
# 734   5617035264  <class 'dict'>         7
# 1127  5614774720  <class 'dict'>         7
# 1165  5355809600  <class 'dict'>         7
# 1247  5614840128  <class 'dict'>         7
# 1275  5614841408  <class 'dict'>         7
# 1315  5614839232  <class 'dict'>         7
# 1601  5357957056  <class 'dict'>         7
# 1682  5614748800  <class 'dict'>         7
# 1763  5614843712  <class 'dict'>         7
# 1844  5357849024  <class 'dict'>         7
# 73    5616140800  <class 'dict'>         6
# 147   5616143808  <class 'dict'>         6
# 276   5616166336  <class 'dict'>         6
# 315   5616127808  <class 'dict'>         6
# 354   5616190848  <class 'dict'>         6
# 393   5616192320  <class 'dict'>         6
# 434   5616199552  <class 'dict'>         6
# 533   5616211584  <class 'dict'>         6
# 614   5617087232  <class 'dict'>         6
# 695   5617034752  <class 'dict'>         6
# 774   5617024640  <class 'dict'>         6
# 823   5339295616  <class 'dict'>         6
# 871   5616751040  <class 'dict'>         6
#
#                                                    repr  size
# 2     {'depends': [], 'executor': '_parsl_internal',...  1176
# 40    {'depends': [], 'executor': '_parsl_internal',...  1176
# 122   {'depends': [<AppFuture at 0x13e7b2550 state=f...  1176
# 172   {'depends': [<AppFuture at 0x13e7b2ac0 state=f...  1176
# 473   {'depends': [<AppFuture at 0x13e84d400 state=f...  1176
# 572   {'depends': [<AppFuture at 0x13e84da30 state=f...  1176
# 653   {'depends': [<AppFuture at 0x14e9c7ca0 state=f...  1176
# 734   {'depends': [<AppFuture at 0x13e6e7cd0 state=f...  1176
# 1127  {'depends': [], 'executor': '_parsl_internal',...  1176
# 1165  {'depends': [], 'executor': '_parsl_internal',...  1176
# 1247  {'depends': [<AppFuture at 0x107705970 state=f...  1176
# 1275  {'depends': [<AppFuture at 0x107705220 state=f...  1176
# 1315  {'depends': [<AppFuture at 0x107705220 state=f...  1176
# 1601  {'depends': [<AppFuture at 0x10774ce20 state=f...  1176
# 1682  {'depends': [<AppFuture at 0x107760490 state=f...  1176
# 1763  {'depends': [<AppFuture at 0x1077604c0 state=f...  1176
# 1844  {'depends': [<AppFuture at 0x1075a4d30 state=f...  1176
# 73    {'depends': [], 'executor': 'local_threads', '...  1176
# 147   {'depends': [<AppFuture at 0x13e7b2ac0 state=f...  1176
# 276   {'depends': [], 'executor': 'local_threads', '...  1176
# 315   {'depends': [], 'executor': 'local_threads', '...  1176
# 354   {'depends': [], 'executor': 'local_threads', '...  1176
# 393   {'depends': [], 'executor': 'local_threads', '...  1176
# 434   {'depends': [], 'executor': 'local_threads', '...  1176
# 533   {'depends': [], 'executor': 'local_threads', '...  1176
# 614   {'depends': [], 'executor': 'local_threads', '...  1176
# 695   {'depends': [], 'executor': 'local_threads', '...  1176
# 774   {'depends': [], 'executor': 'local_threads', '...  1176
# 823   {'depends': [], 'executor': 'local_threads', '...  1176
# 871   {'depends': [], 'executor': 'local_threads', '...  1176

# %%
df[
    ~df["repr"].str.contains("AppFuture") & ~df["repr"].str.contains("deque")
].sort_values(by=["size", "refcount"], ascending=False).drop_duplicates(
    subset="id"
).head(
    30
).to_csv(
    "leaks.csv"
)

# %%
df.sort_values(by="refcount", ascending=False).drop_duplicates(subset="id")[
    "type"
].value_counts()
# Out:
# type
# <class 'list'>                                558
# <class 'builtin_function_or_method'>          520
# <class 'dict'>                                346
# <class 'tuple'>                               134
# <class 'method'>                              107
# <class 'functools.partial'>                   107
# <class 'collections.deque'>                   104
# <class 'threading.Condition'>                 104
# <class 'parsl.dataflow.futures.AppFuture'>     52
# <class 'concurrent.futures._base.Future'>      52
# <class 'cell'>                                 51
# <class 'pathlib.PosixPath'>                    26
# <class 'function'>                             23
# <class 'pyarrow._parquet.ParquetSchema'>       18
# <class 'pyarrow._parquet.FileMetaData'>        18
# <class 'cython_function_or_method'>             6
# <class 'collections.OrderedDict'>               2
# <class 'getset_descriptor'>                     2
# <class 'pyarrow._s3fs.__Pyx_EnumMeta'>          1
# <class 'pyarrow._fs.__Pyx_EnumMeta'>            1
# Name: count, dtype: int64
